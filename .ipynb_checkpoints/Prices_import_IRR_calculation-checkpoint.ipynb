# %% [markdown]
# # Bonds prices import

# %%
import pandas as pd
pd.core.common.is_list_like = pd.api.types.is_list_like
import pandas_datareader as web
from pandas_datareader.moex import MoexReader
import numpy as np

# %%
bonds_payments = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Data/2016_bonds_payments.csv', index_col=0)
bonds_payments['Дата фактической выплаты'] = pd.to_datetime(bonds_payments['Дата фактической выплаты'])

# %%
bond_trade_codes = bonds_payments['Торговый код'].unique()

# %%
bonds_list = [MoexReader(code, start = '01.01.2016', end = '31.12.2016').read() for code in bond_trade_codes]
bonds_list = [bonds_list[i][bonds_list[i].BOARDID == 'TQOB'].drop_duplicates()['CLOSE'] for i in range(len(bonds_list))]

for i in range(len(bond_trade_codes)):
    bonds_list[i].name = bond_trade_codes[i]
    
bonds_prices = pd.concat(bonds_list, axis = 1)
bonds_prices.head()
# Out:
#             SU26205RMFS3  SU26207RMFS9  SU26208RMFS7  SU26209RMFS5  \
# TRADEDATE
# 2016-01-04       92.3500       91.8999       94.6000           NaN
# 2016-01-05       92.3500       91.9995       94.3999       91.3000
# 2016-01-06       92.0999       91.5999       94.4000       91.2000
# 2016-01-11       90.4499       89.2999       93.2899       88.7000
# 2016-01-12       89.2510       87.8001       92.9899       87.5011
#
#             SU26210RMFS3  SU26211RMFS1  SU26212RMFS9  SU26214RMFS5  \
# TRADEDATE
# 2016-01-04           NaN           NaN       83.9998           NaN
# 2016-01-05       91.3004       87.6996       84.1000       88.7500
# 2016-01-06       90.8900       87.6999       83.7494       88.6500
# 2016-01-11       89.5000       85.5007       80.8000       87.4000
# 2016-01-12       88.9649       84.1501       79.6579       86.3007
#
#             SU26215RMFS2  SU26216RMFS0  SU26217RMFS8  SU26218RMFS6  \
# TRADEDATE
# 2016-01-04       86.7400           NaN           NaN           NaN
# 2016-01-05       87.1764       92.0500           NaN           NaN
# 2016-01-06       86.6000       91.7200           NaN           NaN
# 2016-01-11       84.2500       90.7900           NaN           NaN
# 2016-01-12       83.5001       89.8102           NaN           NaN
#
#             SU26219RMFS4  SU46011RMFS1  SU46012RMFS9  SU46018RMFS6  \
# TRADEDATE
# 2016-01-04           NaN           NaN           NaN           NaN
# 2016-01-05           NaN           NaN           NaN           NaN
# 2016-01-06           NaN           NaN          88.0         91.97
# 2016-01-11           NaN           NaN           NaN           NaN
# 2016-01-12           NaN           NaN           NaN         86.00
#
#             SU46019RMFS4  SU46020RMFS2  SU46022RMFS8  SU46023RMFS6
# TRADEDATE
# 2016-01-04           NaN           NaN           NaN           NaN
# 2016-01-05           NaN        77.448           NaN           NaN
# 2016-01-06           NaN        77.991         83.31           NaN
# 2016-01-11           NaN        76.990           NaN         109.2
# 2016-01-12           NaN        76.000           NaN           NaN

# %%
bonds_prices.to_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Data/bonds_prices.csv')

# %% [markdown]
# # IRR calcultation

# %%
dates = bonds_prices.index

# %%
def npv(irr, cfs, yrs):  
    return np.sum(cfs / (1. + irr) ** yrs)

# %%
from scipy.optimize import fsolve

def irr(cfs, yrs, x0):
    return np.asscalar(fsolve(npv, x0=x0, args=(cfs, yrs)))

# %%
def maturities_irrs(date_number):
    irrs = []
    maturities = []
    payments_on_date = bonds_payments[bonds_payments['Дата фактической выплаты'] >= dates[date_number]]
    
    for ticker in bonds_payments['Торговый код'].unique():
    
        payments = payments_on_date[payments_on_date['Торговый код'] == ticker]['Сумма купона, RUB'] + payments_on_date[payments_on_date['Торговый код'] == ticker]['Погашение номинала, RUB'].values
        payments_dates = (payments_on_date[payments_on_date['Торговый код'] == ticker]['Дата фактической выплаты'] - dates[date_number]).apply(lambda x: x.days)/365
    
        investment = bonds_prices.iloc[date_number][ticker]
        payments = np.insert(np.array(payments), 0, -investment)
        payments_dates = np.insert(np.array(payments_dates), 0, 0)
        
        if np.isnan(payments[0]) == True:
            irrs.append(np.nan)
            maturities.append(np.nan)
        else:
            bond_irr = irr(cfs=payments, yrs=payments_dates, x0=0.10)
            irrs.append(bond_irr)
            maturities.append(payments_dates[-1])
        
    return (np.array([maturities]), np.array([irrs]))

# %%
irr_matrix = pd.DataFrame(np.zeros([252, 20]), index = dates, columns = bonds_payments['Торговый код'].unique())
maturity_matrix = pd.DataFrame(np.zeros([252, 20]), index = dates, columns = bonds_payments['Торговый код'].unique())

# %%
for i in range(len(dates)):
    maturity_matrix[dates[i]:dates[i]], irr_matrix[dates[i]:dates[i]] = maturities_irrs(i)

# %%
maturity_matrix.to_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Data/bonds_maturities.csv')
irr_matrix.to_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Data/bonds_irrs.csv')

# %%
# %%bash
# say finished

# %%
maturity_matrix.head()
# Out:
#             SU26205RMFS3  SU26207RMFS9  SU26208RMFS7  SU26209RMFS5  \
# TRADEDATE
# 2016-01-04      5.279452     11.164384      3.150685           NaN
# 2016-01-05      5.276712     11.161644      3.147945      6.542466
# 2016-01-06      5.273973     11.158904      3.145205      6.539726
# 2016-01-11      5.260274     11.145205      3.131507      6.526027
# 2016-01-12      5.257534     11.142466      3.128767      6.523288
#
#             SU26210RMFS3  SU26211RMFS1  SU26212RMFS9  SU26214RMFS5  \
# TRADEDATE
# 2016-01-04           NaN           NaN     12.049315           NaN
# 2016-01-05      3.854795      7.060274     12.046575      4.394521
# 2016-01-06      3.852055      7.057534     12.043836      4.391781
# 2016-01-11      3.838356      7.043836     12.030137      4.378082
# 2016-01-12      3.835616      7.041096     12.027397      4.375342
#
#             SU26215RMFS2  SU26216RMFS0  SU26217RMFS8  SU26218RMFS6  \
# TRADEDATE
# 2016-01-04      7.619178           NaN           NaN           NaN
# 2016-01-05      7.616438      3.358904           NaN           NaN
# 2016-01-06      7.613699      3.356164           NaN           NaN
# 2016-01-11      7.600000      3.342466           NaN           NaN
# 2016-01-12      7.597260      3.339726           NaN           NaN
#
#             SU26219RMFS4  SU46011RMFS1  SU46012RMFS9  SU46018RMFS6  \
# TRADEDATE
# 2016-01-04           NaN           NaN           NaN           NaN
# 2016-01-05           NaN           NaN           NaN           NaN
# 2016-01-06           NaN           NaN     13.347945      5.887671
# 2016-01-11           NaN           NaN           NaN           NaN
# 2016-01-12           NaN           NaN           NaN      5.871233
#
#             SU46019RMFS4  SU46020RMFS2  SU46022RMFS8  SU46023RMFS6
# TRADEDATE
# 2016-01-04           NaN           NaN           NaN           NaN
# 2016-01-05           NaN     20.421918           NaN           NaN
# 2016-01-06           NaN     20.419178      7.536986           NaN
# 2016-01-11           NaN     20.405479           NaN     10.536986
# 2016-01-12           NaN     20.402740           NaN           NaN

# %%
irr_matrix.head()
# Out:
#             SU26205RMFS3  SU26207RMFS9  SU26208RMFS7  SU26209RMFS5  \
# TRADEDATE
# 2016-01-04      0.101207      0.098895      0.108341           NaN
# 2016-01-05      0.101274      0.098768      0.109304      0.104196
# 2016-01-06      0.102033      0.099476      0.109418      0.104499
# 2016-01-11      0.107020      0.103616      0.114789      0.111017
# 2016-01-12      0.110543      0.106310      0.116223      0.114153
#
#             SU26210RMFS3  SU26211RMFS1  SU26212RMFS9  SU26214RMFS5  \
# TRADEDATE
# 2016-01-04           NaN           NaN      0.100657           NaN
# 2016-01-05      0.100423      0.104188      0.100520      0.100552
# 2016-01-06      0.101960      0.104244      0.101174      0.100953
# 2016-01-11      0.107401      0.109876      0.106719      0.095069
# 2016-01-12      0.109452      0.113322      0.108913      0.098659
#
#             SU26215RMFS2  SU26216RMFS0  SU26217RMFS8  SU26218RMFS6  \
# TRADEDATE
# 2016-01-04      0.102537           NaN           NaN           NaN
# 2016-01-05      0.101618      0.100892           NaN           NaN
# 2016-01-06      0.102954      0.102300           NaN           NaN
# 2016-01-11      0.108592      0.106542           NaN           NaN
# 2016-01-12      0.110409      0.110660           NaN           NaN
#
#             SU26219RMFS4  SU46011RMFS1  SU46012RMFS9  SU46018RMFS6  \
# TRADEDATE
# 2016-01-04           NaN           NaN           NaN           NaN
# 2016-01-05           NaN           NaN           NaN           NaN
# 2016-01-06           NaN           NaN      0.084418      0.089747
# 2016-01-11           NaN           NaN           NaN           NaN
# 2016-01-12           NaN           NaN           NaN      0.102876
#
#             SU46019RMFS4  SU46020RMFS2  SU46022RMFS8  SU46023RMFS6
# TRADEDATE
# 2016-01-04           NaN           NaN           NaN           NaN
# 2016-01-05           NaN      0.098403           NaN           NaN
# 2016-01-06           NaN      0.097637      0.098167           NaN
# 2016-01-11           NaN      0.099259           NaN      0.070714
# 2016-01-12           NaN      0.100781           NaN           NaN

# %%
(irr_matrix < 0).sum()
# Out:
# SU26205RMFS3      0
# SU26207RMFS9      0
# SU26208RMFS7      0
# SU26209RMFS5      0
# SU26210RMFS3      0
# SU26211RMFS1      0
# SU26212RMFS9      0
# SU26214RMFS5      0
# SU26215RMFS2      0
# SU26216RMFS0      0
# SU26217RMFS8      0
# SU26218RMFS6      0
# SU26219RMFS4      0
# SU46011RMFS1      0
# SU46012RMFS9      0
# SU46018RMFS6      0
# SU46019RMFS4    132
# SU46020RMFS2      0
# SU46022RMFS8      0
# SU46023RMFS6      0
# dtype: int64

# %%
irr_matrix['SU46019RMFS4']
# Out:
# TRADEDATE
# 2016-01-04         NaN
# 2016-01-05         NaN
# 2016-01-06         NaN
# 2016-01-11         NaN
# 2016-01-12         NaN
# 2016-01-13         NaN
# 2016-01-14         NaN
# 2016-01-15         NaN
# 2016-01-18         NaN
# 2016-01-19         NaN
# 2016-01-20         NaN
# 2016-01-21         NaN
# 2016-01-22         NaN
# 2016-01-25         NaN
# 2016-01-26         NaN
# 2016-01-27         NaN
# 2016-01-28         NaN
# 2016-01-29   -0.089646
# 2016-02-01         NaN
# 2016-02-02         NaN
# 2016-02-03         NaN
# 2016-02-04         NaN
# 2016-02-05   -0.090235
# 2016-02-08         NaN
# 2016-02-09         NaN
# 2016-02-10         NaN
# 2016-02-11         NaN
# 2016-02-12         NaN
# 2016-02-15   -0.085089
# 2016-02-16   -0.083513
#                 ...
# 2016-11-21   -0.239190
# 2016-11-22   -0.240404
# 2016-11-23         NaN
# 2016-11-24         NaN
# 2016-11-25   -0.241558
# 2016-11-28   -0.242723
# 2016-11-29   -0.245008
# 2016-11-30   -0.244064
# 2016-12-01         NaN
# 2016-12-02   -0.244964
# 2016-12-05         NaN
# 2016-12-06         NaN
# 2016-12-07   -0.249256
# 2016-12-08         NaN
# 2016-12-09         NaN
# 2016-12-12   -0.248920
# 2016-12-13   -0.246998
# 2016-12-14   -0.253001
# 2016-12-15   -0.253471
# 2016-12-16   -0.253886
# 2016-12-19   -0.255139
# 2016-12-20   -0.257255
# 2016-12-21   -0.256263
# 2016-12-22   -0.255274
# 2016-12-23   -0.257275
# 2016-12-26         NaN
# 2016-12-27   -0.259218
# 2016-12-28   -0.259089
# 2016-12-29   -0.259969
# 2016-12-30   -0.262664
# Name: SU46019RMFS4, Length: 252, dtype: float64

# %%
bonds_payments[bonds_payments['Торговый код'] == 'SU46019RMFS4']
# Out:
#      Бумага          ISIN  Торговый код  Номер платежа  \
# 375   46019  RU000A0JNHJ4  SU46019RMFS4              1
# 376   46019  RU000A0JNHJ4  SU46019RMFS4              2
# 377   46019  RU000A0JNHJ4  SU46019RMFS4              3
# 378   46019  RU000A0JNHJ4  SU46019RMFS4              4
# 379   46019  RU000A0JNHJ4  SU46019RMFS4              5
# 380   46019  RU000A0JNHJ4  SU46019RMFS4              6
# 381   46019  RU000A0JNHJ4  SU46019RMFS4              7
# 382   46019  RU000A0JNHJ4  SU46019RMFS4              8
# 383   46019  RU000A0JNHJ4  SU46019RMFS4              9
# 384   46019  RU000A0JNHJ4  SU46019RMFS4             10
# 385   46019  RU000A0JNHJ4  SU46019RMFS4             11
# 386   46019  RU000A0JNHJ4  SU46019RMFS4             12
# 387   46019  RU000A0JNHJ4  SU46019RMFS4             13
# 388   46019  RU000A0JNHJ4  SU46019RMFS4             14
#
#     Дата фактической выплаты  Ставка купона, % годовых  Сумма купона, RUB  \
# 375               2006-05-04                     0.000                0.0
# 376               2007-04-04                     0.000                0.0
# 377               2008-02-04                     0.000                0.0
# 378               2009-01-04                     0.000                0.0
# 379               2010-03-31                     0.000                0.0
# 380               2011-03-30                     0.000                0.0
# 381               2012-03-28                     0.000                0.0
# 382               2013-03-27                     3.008                3.0
# 383               2014-03-26                     2.005                1.8
# 384               2015-03-25                     2.005                1.6
# 385               2016-03-23                     2.005                1.4
# 386               2017-03-22                     2.005                1.2
# 387               2018-03-21                     2.005                0.8
# 388               2019-03-20                     2.005                0.4
#
#      Погашение номинала, RUB
# 375                      0.0
# 376                      0.0
# 377                      0.0
# 378                      0.0
# 379                      0.0
# 380                      0.0
# 381                      0.0
# 382                     10.0
# 383                     10.0
# 384                     10.0
# 385                     10.0
# 386                     20.0
# 387                     20.0
# 388                     20.0

# %%
bonds_prices['SU46019RMFS4']
# Out:
# TRADEDATE
# 2016-01-04        NaN
# 2016-01-05        NaN
# 2016-01-06        NaN
# 2016-01-11        NaN
# 2016-01-12        NaN
# 2016-01-13        NaN
# 2016-01-14        NaN
# 2016-01-15        NaN
# 2016-01-18        NaN
# 2016-01-19        NaN
# 2016-01-20        NaN
# 2016-01-21        NaN
# 2016-01-22        NaN
# 2016-01-25        NaN
# 2016-01-26        NaN
# 2016-01-27        NaN
# 2016-01-28        NaN
# 2016-01-29    88.0000
# 2016-02-01        NaN
# 2016-02-02        NaN
# 2016-02-03        NaN
# 2016-02-04        NaN
# 2016-02-05    87.9500
# 2016-02-08        NaN
# 2016-02-09        NaN
# 2016-02-10        NaN
# 2016-02-11        NaN
# 2016-02-12        NaN
# 2016-02-15    86.7998
# 2016-02-16    86.5000
#                ...
# 2016-11-21    91.6500
# 2016-11-22    91.8000
# 2016-11-23        NaN
# 2016-11-24        NaN
# 2016-11-25    91.8000
# 2016-11-28    91.8000
# 2016-11-29    92.1405
# 2016-11-30    91.9000
# 2016-12-01        NaN
# 2016-12-02    91.9200
# 2016-12-05        NaN
# 2016-12-06        NaN
# 2016-12-07    92.3314
# 2016-12-08        NaN
# 2016-12-09        NaN
# 2016-12-12    91.9100
# 2016-12-13    91.5000
# 2016-12-14    92.4900
# 2016-12-15    92.5000
# 2016-12-16    92.4999
# 2016-12-19    92.4998
# 2016-12-20    92.8020
# 2016-12-21    92.5500
# 2016-12-22    92.3000
# 2016-12-23    92.5790
# 2016-12-26        NaN
# 2016-12-27    92.6200
# 2016-12-28    92.5212
# 2016-12-29    92.6000
# 2016-12-30    93.0000
# Name: SU46019RMFS4, Length: 252, dtype: float64

# %% [markdown]
# Странно, что есть облигация с отрицательной нормой доходности. Я не могу найти ошибку ни в своих данных, ни в расчетах. Более того, наблюдаемая IRR сходится со данными по облигации.

# %%
bond_s4 = MoexReader('SU46019RMFS4', start = '01.01.2016', end = '31.12.2016').read()

# %%
bond_s4
# Out:
#            BOARDID  SHORTNAME         SECID  NUMTRADES        VALUE      LOW  \
# TRADEDATE
# 2016-01-05    TQOB  ОФЗ 46019  SU46019RMFS4          0         0.00      NaN
# 2016-01-06    TQOB  ОФЗ 46019  SU46019RMFS4          0         0.00      NaN
# 2016-01-11    TQOB  ОФЗ 46019  SU46019RMFS4          0         0.00      NaN
# 2016-01-12    TQOB  ОФЗ 46019  SU46019RMFS4          0         0.00      NaN
# 2016-01-13    TQOB  ОФЗ 46019  SU46019RMFS4          0         0.00      NaN
# 2016-01-14    TQOB  ОФЗ 46019  SU46019RMFS4          0         0.00      NaN
# 2016-01-15    TQOB  ОФЗ 46019  SU46019RMFS4          0         0.00      NaN
# 2016-01-18    TQOB  ОФЗ 46019  SU46019RMFS4          0         0.00      NaN
# 2016-01-19    TQOB  ОФЗ 46019  SU46019RMFS4          0         0.00      NaN
# 2016-01-20    TQOB  ОФЗ 46019  SU46019RMFS4          0         0.00      NaN
# 2016-01-21    TQOB  ОФЗ 46019  SU46019RMFS4          0         0.00      NaN
# 2016-01-22    TQOB  ОФЗ 46019  SU46019RMFS4          0         0.00      NaN
# 2016-01-25    TQOB  ОФЗ 46019  SU46019RMFS4          0         0.00      NaN
# 2016-01-26    TQOB  ОФЗ 46019  SU46019RMFS4          0         0.00      NaN
# 2016-01-27    TQOB  ОФЗ 46019  SU46019RMFS4          0         0.00      NaN
# 2016-01-28    TQOB  ОФЗ 46019  SU46019RMFS4          0         0.00      NaN
# 2016-01-29    TQOB  ОФЗ 46019  SU46019RMFS4          1       616.00  88.0000
# 2016-02-01    TQOB  ОФЗ 46019  SU46019RMFS4          0         0.00      NaN
# 2016-02-02    TQOB  ОФЗ 46019  SU46019RMFS4          0         0.00      NaN
# 2016-02-03    TQOB  ОФЗ 46019  SU46019RMFS4          0         0.00      NaN
# 2016-02-04    TQOB  ОФЗ 46019  SU46019RMFS4          0         0.00      NaN
# 2016-02-05    TQOB  ОФЗ 46019  SU46019RMFS4          2     33340.65  85.0000
# 2016-02-08    TQOB  ОФЗ 46019  SU46019RMFS4          0         0.00      NaN
# 2016-02-09    TQOB  ОФЗ 46019  SU46019RMFS4          0         0.00      NaN
# 2016-02-10    TQOB  ОФЗ 46019  SU46019RMFS4          0         0.00      NaN
# 2016-02-11    TQOB  ОФЗ 46019  SU46019RMFS4          0         0.00      NaN
# 2016-02-12    TQOB  ОФЗ 46019  SU46019RMFS4          0         0.00      NaN
# 2016-02-15    TQOB  ОФЗ 46019  SU46019RMFS4          5     15798.98  86.7998
# 2016-02-16    TQOB  ОФЗ 46019  SU46019RMFS4         19   7451422.58  86.0402
# 2016-02-17    TQOB  ОФЗ 46019  SU46019RMFS4          1       605.85  86.5500
# ...            ...        ...           ...        ...          ...      ...
# 2016-11-21    TQOB  ОФЗ 46019  SU46019RMFS4          6      6050.40  91.6500
# 2016-11-22    TQOB  ОФЗ 46019  SU46019RMFS4          3     22574.40  90.4001
# 2016-11-23    TQOB  ОФЗ 46019  SU46019RMFS4          0         0.00      NaN
# 2016-11-24    TQOB  ОФЗ 46019  SU46019RMFS4          0         0.00      NaN
# 2016-11-25    TQOB  ОФЗ 46019  SU46019RMFS4          3     24235.20  91.8000
# 2016-11-28    TQOB  ОФЗ 46019  SU46019RMFS4          2     21481.20  91.8000
# 2016-11-29    TQOB  ОФЗ 46019  SU46019RMFS4          1       552.84  92.1405
# 2016-11-30    TQOB  ОФЗ 46019  SU46019RMFS4          2     13234.82  91.9000
# 2016-12-01    TQOB  ОФЗ 46019  SU46019RMFS4          0         0.00      NaN
# 2016-12-02    TQOB  ОФЗ 46019  SU46019RMFS4          6    108093.16  91.9000
# 2016-12-05    TQOB  ОФЗ 46019  SU46019RMFS4          0         0.00      NaN
# 2016-12-06    TQOB  ОФЗ 46019  SU46019RMFS4          0         0.00      NaN
# 2016-12-07    TQOB  ОФЗ 46019  SU46019RMFS4          1      2769.94  92.3314
# 2016-12-08    TQOB  ОФЗ 46019  SU46019RMFS4          0         0.00      NaN
# 2016-12-09    TQOB  ОФЗ 46019  SU46019RMFS4          0         0.00      NaN
# 2016-12-12    TQOB  ОФЗ 46019  SU46019RMFS4          1       551.46  91.9100
# 2016-12-13    TQOB  ОФЗ 46019  SU46019RMFS4          2     27450.01  91.5000
# 2016-12-14    TQOB  ОФЗ 46019  SU46019RMFS4          2      1110.54  92.4900
# 2016-12-15    TQOB  ОФЗ 46019  SU46019RMFS4          2      3330.00  92.5000
# 2016-12-16    TQOB  ОФЗ 46019  SU46019RMFS4          1       555.00  92.4999
# 2016-12-19    TQOB  ОФЗ 46019  SU46019RMFS4          1       555.00  92.4998
# 2016-12-20    TQOB  ОФЗ 46019  SU46019RMFS4          4     98555.72  92.8019
# 2016-12-21    TQOB  ОФЗ 46019  SU46019RMFS4          1   1701994.50  92.5500
# 2016-12-22    TQOB  ОФЗ 46019  SU46019RMFS4         12  75735955.45  92.0000
# 2016-12-23    TQOB  ОФЗ 46019  SU46019RMFS4          1     13886.85  92.5790
# 2016-12-26    TQOB  ОФЗ 46019  SU46019RMFS4          0         0.00      NaN
# 2016-12-27    TQOB  ОФЗ 46019  SU46019RMFS4          2     98361.54  92.5900
# 2016-12-28    TQOB  ОФЗ 46019  SU46019RMFS4          2      1109.66  92.4224
# 2016-12-29    TQOB  ОФЗ 46019  SU46019RMFS4         10     74913.24  91.7101
# 2016-12-30    TQOB  ОФЗ 46019  SU46019RMFS4          1    164052.00  93.0000
#
#                HIGH    CLOSE  LEGALCLOSEPRICE  ACCINT    ...     COUPONVALUE  \
# TRADEDATE                                                ...
# 2016-01-05      NaN      NaN          88.0000   11.00    ...             NaN
# 2016-01-06      NaN      NaN          88.0000   11.04    ...             NaN
# 2016-01-11      NaN      NaN          88.0000   11.23    ...             NaN
# 2016-01-12      NaN      NaN          88.0000   11.27    ...             NaN
# 2016-01-13      NaN      NaN          88.0000   11.31    ...             NaN
# 2016-01-14      NaN      NaN          88.0000   11.35    ...             NaN
# 2016-01-15      NaN      NaN          88.0000   11.38    ...             NaN
# 2016-01-18      NaN      NaN          88.0000   11.50    ...             NaN
# 2016-01-19      NaN      NaN          88.0000   11.54    ...             NaN
# 2016-01-20      NaN      NaN          88.0000   11.58    ...             NaN
# 2016-01-21      NaN      NaN          88.0000   11.62    ...             NaN
# 2016-01-22      NaN      NaN          88.0000   11.65    ...             NaN
# 2016-01-25      NaN      NaN          88.0000   11.77    ...             NaN
# 2016-01-26      NaN      NaN          88.0000   11.81    ...             NaN
# 2016-01-27      NaN      NaN          88.0000   11.85    ...             NaN
# 2016-01-28      NaN      NaN          88.0000   11.88    ...             NaN
# 2016-01-29  88.0000  88.0000          88.0000   11.92    ...             NaN
# 2016-02-01      NaN      NaN          88.0000   12.04    ...             NaN
# 2016-02-02      NaN      NaN          88.0000   12.08    ...             NaN
# 2016-02-03      NaN      NaN          88.0000   12.12    ...             NaN
# 2016-02-04      NaN      NaN          88.0000   12.15    ...             NaN
# 2016-02-05  87.9500  87.9500          87.9500   12.19    ...             NaN
# 2016-02-08      NaN      NaN          87.9500   12.31    ...             NaN
# 2016-02-09      NaN      NaN          87.9500   12.35    ...             NaN
# 2016-02-10      NaN      NaN          87.9500   12.38    ...             NaN
# 2016-02-11      NaN      NaN          87.9500   12.42    ...             NaN
# 2016-02-12      NaN      NaN          87.9500   12.46    ...             NaN
# 2016-02-15  87.0000  86.7998          86.7999   12.58    ...             NaN
# 2016-02-16  86.8000  86.5000          86.5000   12.62    ...             NaN
# 2016-02-17  86.5500  86.5500          86.5500   12.65    ...             NaN
# ...             ...      ...              ...     ...    ...             ...
# 2016-11-21  91.7000  91.6500          91.6500    8.01    ...             NaN
# 2016-11-22  91.8000  91.8000          91.8000    8.04    ...             NaN
# 2016-11-23      NaN      NaN          91.8000    8.08    ...             NaN
# 2016-11-24      NaN      NaN          91.8000    8.11    ...             NaN
# 2016-11-25  91.8001  91.8000          91.8000    8.14    ...             NaN
# 2016-11-28  91.8000  91.8000          91.8000    8.24    ...             NaN
# 2016-11-29  92.1405  92.1405          92.1400    8.27    ...             NaN
# 2016-11-30  92.1035  91.9000          91.9000    8.31    ...             NaN
# 2016-12-01      NaN      NaN          91.9000    8.34    ...             NaN
# 2016-12-02  91.9200  91.9200          91.9200    8.37    ...             NaN
# 2016-12-05      NaN      NaN          91.9200    8.47    ...             NaN
# 2016-12-06      NaN      NaN          91.9200    8.51    ...             NaN
# 2016-12-07  92.3314  92.3314          92.3313    8.54    ...             NaN
# 2016-12-08      NaN      NaN          92.3313    8.57    ...             NaN
# 2016-12-09      NaN      NaN          92.3313    8.60    ...             NaN
# 2016-12-12  91.9100  91.9100          91.9100    8.70    ...             NaN
# 2016-12-13  91.5001  91.5000          91.5000    8.74    ...             NaN
# 2016-12-14  92.5999  92.4900          92.4900    8.77    ...             NaN
# 2016-12-15  92.5000  92.5000          92.5000    8.80    ...             NaN
# 2016-12-16  92.4999  92.4999          92.5000    8.84    ...             NaN
# 2016-12-19  92.4998  92.4998          92.5000    8.93    ...             NaN
# 2016-12-20  92.8020  92.8020          92.8020    8.97    ...             NaN
# 2016-12-21  92.5500  92.5500          92.5500    9.00    ...             NaN
# 2016-12-22  92.3000  92.3000          92.3000    9.03    ...             NaN
# 2016-12-23  92.5790  92.5790          92.5790    9.07    ...             NaN
# 2016-12-26      NaN      NaN          92.5790    9.16    ...             NaN
# 2016-12-27  92.6200  92.6200          92.6192    9.20    ...             NaN
# 2016-12-28  92.5212  92.5212          92.4717    9.23    ...             NaN
# 2016-12-29  92.6500  92.6000          92.6000    9.26    ...             NaN
# 2016-12-30  93.0000  93.0000          93.0000    9.30    ...             NaN
#
#             BUYBACKDATE  LASTTRADEDATE  FACEVALUE  CURRENCYID  CBRCLOSE  \
# TRADEDATE
# 2016-01-05          NaN            NaN        700         SUR       NaN
# 2016-01-06          NaN            NaN        700         SUR       NaN
# 2016-01-11          NaN            NaN        700         SUR       NaN
# 2016-01-12          NaN            NaN        700         SUR       NaN
# 2016-01-13          NaN            NaN        700         SUR       NaN
# 2016-01-14          NaN            NaN        700         SUR       NaN
# 2016-01-15          NaN            NaN        700         SUR       NaN
# 2016-01-18          NaN            NaN        700         SUR       NaN
# 2016-01-19          NaN            NaN        700         SUR       NaN
# 2016-01-20          NaN            NaN        700         SUR       NaN
# 2016-01-21          NaN            NaN        700         SUR       NaN
# 2016-01-22          NaN            NaN        700         SUR       NaN
# 2016-01-25          NaN            NaN        700         SUR       NaN
# 2016-01-26          NaN            NaN        700         SUR       NaN
# 2016-01-27          NaN            NaN        700         SUR       NaN
# 2016-01-28          NaN            NaN        700         SUR       NaN
# 2016-01-29          NaN            NaN        700         SUR       NaN
# 2016-02-01          NaN            NaN        700         SUR       NaN
# 2016-02-02          NaN            NaN        700         SUR       NaN
# 2016-02-03          NaN            NaN        700         SUR       NaN
# 2016-02-04          NaN            NaN        700         SUR       NaN
# 2016-02-05          NaN            NaN        700         SUR       NaN
# 2016-02-08          NaN            NaN        700         SUR       NaN
# 2016-02-09          NaN            NaN        700         SUR       NaN
# 2016-02-10          NaN            NaN        700         SUR       NaN
# 2016-02-11          NaN            NaN        700         SUR       NaN
# 2016-02-12          NaN            NaN        700         SUR       NaN
# 2016-02-15          NaN            NaN        700         SUR       NaN
# 2016-02-16          NaN            NaN        700         SUR       NaN
# 2016-02-17          NaN            NaN        700         SUR       NaN
# ...                 ...            ...        ...         ...       ...
# 2016-11-21          NaN            NaN        600         SUR       NaN
# 2016-11-22          NaN            NaN        600         SUR       NaN
# 2016-11-23          NaN            NaN        600         SUR       NaN
# 2016-11-24          NaN            NaN        600         SUR       NaN
# 2016-11-25          NaN            NaN        600         SUR       NaN
# 2016-11-28          NaN            NaN        600         SUR       NaN
# 2016-11-29          NaN            NaN        600         SUR       NaN
# 2016-11-30          NaN            NaN        600         SUR       NaN
# 2016-12-01          NaN            NaN        600         SUR       NaN
# 2016-12-02          NaN            NaN        600         SUR       NaN
# 2016-12-05          NaN            NaN        600         SUR       NaN
# 2016-12-06          NaN            NaN        600         SUR       NaN
# 2016-12-07          NaN            NaN        600         SUR       NaN
# 2016-12-08          NaN            NaN        600         SUR       NaN
# 2016-12-09          NaN            NaN        600         SUR       NaN
# 2016-12-12          NaN            NaN        600         SUR       NaN
# 2016-12-13          NaN            NaN        600         SUR       NaN
# 2016-12-14          NaN            NaN        600         SUR       NaN
# 2016-12-15          NaN            NaN        600         SUR       NaN
# 2016-12-16          NaN            NaN        600         SUR       NaN
# 2016-12-19          NaN            NaN        600         SUR       NaN
# 2016-12-20          NaN            NaN        600         SUR       NaN
# 2016-12-21          NaN            NaN        600         SUR       NaN
# 2016-12-22          NaN            NaN        600         SUR       NaN
# 2016-12-23          NaN            NaN        600         SUR       NaN
# 2016-12-26          NaN            NaN        600         SUR       NaN
# 2016-12-27          NaN            NaN        600         SUR       NaN
# 2016-12-28          NaN            NaN        600         SUR       NaN
# 2016-12-29          NaN            NaN        600         SUR       NaN
# 2016-12-30          NaN            NaN        600         SUR       NaN
#
#             YIELDTOOFFER  YIELDLASTCOUPON  OFFERDATE  FACEUNIT
# TRADEDATE
# 2016-01-05           NaN              NaN        NaN       RUB
# 2016-01-06           NaN              NaN        NaN       RUB
# 2016-01-11           NaN              NaN        NaN       RUB
# 2016-01-12           NaN              NaN        NaN       RUB
# 2016-01-13           NaN              NaN        NaN       RUB
# 2016-01-14           NaN              NaN        NaN       RUB
# 2016-01-15           NaN              NaN        NaN       RUB
# 2016-01-18           NaN              NaN        NaN       RUB
# 2016-01-19           NaN              NaN        NaN       RUB
# 2016-01-20           NaN              NaN        NaN       RUB
# 2016-01-21           NaN              NaN        NaN       RUB
# 2016-01-22           NaN              NaN        NaN       RUB
# 2016-01-25           NaN              NaN        NaN       RUB
# 2016-01-26           NaN              NaN        NaN       RUB
# 2016-01-27           NaN              NaN        NaN       RUB
# 2016-01-28           NaN              NaN        NaN       RUB
# 2016-01-29           NaN              NaN        NaN       RUB
# 2016-02-01           NaN              NaN        NaN       RUB
# 2016-02-02           NaN              NaN        NaN       RUB
# 2016-02-03           NaN              NaN        NaN       RUB
# 2016-02-04           NaN              NaN        NaN       RUB
# 2016-02-05           NaN              NaN        NaN       RUB
# 2016-02-08           NaN              NaN        NaN       RUB
# 2016-02-09           NaN              NaN        NaN       RUB
# 2016-02-10           NaN              NaN        NaN       RUB
# 2016-02-11           NaN              NaN        NaN       RUB
# 2016-02-12           NaN              NaN        NaN       RUB
# 2016-02-15           NaN              NaN        NaN       RUB
# 2016-02-16           NaN              NaN        NaN       RUB
# 2016-02-17           NaN              NaN        NaN       RUB
# ...                  ...              ...        ...       ...
# 2016-11-21           NaN              NaN        NaN       RUB
# 2016-11-22           NaN              NaN        NaN       RUB
# 2016-11-23           NaN              NaN        NaN       RUB
# 2016-11-24           NaN              NaN        NaN       RUB
# 2016-11-25           NaN              NaN        NaN       RUB
# 2016-11-28           NaN              NaN        NaN       RUB
# 2016-11-29           NaN              NaN        NaN       RUB
# 2016-11-30           NaN              NaN        NaN       RUB
# 2016-12-01           NaN              NaN        NaN       RUB
# 2016-12-02           NaN              NaN        NaN       RUB
# 2016-12-05           NaN              NaN        NaN       RUB
# 2016-12-06           NaN              NaN        NaN       RUB
# 2016-12-07           NaN              NaN        NaN       RUB
# 2016-12-08           NaN              NaN        NaN       RUB
# 2016-12-09           NaN              NaN        NaN       RUB
# 2016-12-12           NaN              NaN        NaN       RUB
# 2016-12-13           NaN              NaN        NaN       RUB
# 2016-12-14           NaN              NaN        NaN       RUB
# 2016-12-15           NaN              NaN        NaN       RUB
# 2016-12-16           NaN              NaN        NaN       RUB
# 2016-12-19           NaN              NaN        NaN       RUB
# 2016-12-20           NaN              NaN        NaN       RUB
# 2016-12-21           NaN              NaN        NaN       RUB
# 2016-12-22           NaN              NaN        NaN       RUB
# 2016-12-23           NaN              NaN        NaN       RUB
# 2016-12-26           NaN              NaN        NaN       RUB
# 2016-12-27           NaN              NaN        NaN       RUB
# 2016-12-28           NaN              NaN        NaN       RUB
# 2016-12-29           NaN              NaN        NaN       RUB
# 2016-12-30           NaN              NaN        NaN       RUB
#
# [252 rows x 36 columns]
