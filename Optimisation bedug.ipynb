# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from new_thesis_library import *
pd.options.display.max_rows = 999

# %%
bootstraped_rates_list = []

for i in range(len(dates)):
    bootstraped_rates_list.append(pd.read_csv(path + 'Data/New_data/Bootstraped_rates/bt_rates_' + str(dates[i].date()) + '.csv', index_col=0))

# %%
maturity_matrix = pd.read_csv(path + 'Data/New_data/bonds_maturities.csv', index_col='TRADEDATE', parse_dates=True)
irr_matrix = pd.read_csv(path + 'Data/New_data/bonds_irrs.csv', index_col='TRADEDATE', parse_dates=True)

# %%
moex_thetas = pd.read_csv(path + 'Data/New_data/moex_dynamic.csv',
                          sep = ';')

moex_thetas['tradedate'] = pd.to_datetime(moex_thetas['tradedate'], format='%d.%m.%Y')
moex_thetas[['B1', 'B2', 'B3', 'T1']] = moex_thetas[['B1', 'B2', 'B3', 'T1']].apply(lambda x: x.str.replace(',','.'))
moex_thetas[['B1', 'B2', 'B3', 'T1']] = moex_thetas[['B1', 'B2', 'B3', 'T1']].astype('float64')
moex_thetas[['B1', 'B2', 'B3']] = moex_thetas[['B1', 'B2', 'B3']]/10000
moex_thetas = moex_thetas[['tradedate', 'T1', 'B1', 'B2', 'B3']]
moex_thetas.set_index('tradedate', inplace = True)

# %% [markdown]
# ## Recurrent

# %%
bfgs_recurrent = pd.read_csv(path + 'Thetas/l_bfgs_b_recurrent.csv', index_col='TRADEDATE', parse_dates = True)
nelder_mead_recurrent = pd.read_csv(path + 'Thetas/nelder_mead_recurrent.csv', index_col='TRADEDATE', parse_dates = True)
powell_recurrent = pd.read_csv(path + 'Thetas/powell_recurrent.csv', index_col='TRADEDATE', parse_dates = True)
trust_constr_recurrent = pd.read_csv(path + 'Thetas/trust_constr_recurrent.csv', index_col='TRADEDATE', parse_dates = True)

# %%
i = 1600

m = np.linspace(0.1, 30, 300)
plt.figure(figsize = (15, 7.5))
plt.title(dates[i].date())
plt.plot(m, ns(m, bfgs_recurrent[dates[i]:dates[i]].values[0]), label = 'L-BFGS-B')
plt.plot(m, ns(m, nelder_mead_recurrent[dates[i]:dates[i]].values[0]), label = 'Nelder-Mead')
plt.plot(m, ns(m, powell_recurrent[dates[i]:dates[i]].values[0]), label = 'Powell')
plt.plot(m, ns(m, trust_constr_recurrent[dates[i]:dates[i]].values[0]), label = 'Trust Constr')
plt.plot(m, ns(m, moex_thetas[dates[i]:dates[i]].values[0]), label = 'MOEX')
plt.scatter(maturity_matrix[dates[i]:dates[i]], irr_matrix[dates[i]:dates[i]])
plt.grid()
plt.legend()
#plt.scatter(maturity_matrix[dates[i]:dates[i]], irr_matrix[dates[i]:dates[i]])

# %%
i = 257

m = np.linspace(0.1, 30, 300)
plt.figure(figsize = (15, 7.5))
plt.title(dates[i].date())
plt.plot(m, ns(m, bfgs_recurrent[dates[i]:dates[i]].values[0]), label = 'L-BFGS-B')
plt.plot(m, ns(m, nelder_mead_recurrent[dates[i]:dates[i]].values[0]), label = 'Nelder-Mead')
plt.plot(m, ns(m, powell_recurrent[dates[i]:dates[i]].values[0]), label = 'Powell')
plt.plot(m, ns(m, trust_constr_recurrent[dates[i]:dates[i]].values[0]), label = 'Trust Constr')
plt.plot(m, ns(m, moex_thetas[dates[i]:dates[i]].values[0]), label = 'MOEX')
plt.scatter(maturity_matrix[dates[i]:dates[i]], irr_matrix[dates[i]:dates[i]])
plt.grid()
plt.legend()
#plt.scatter(maturity_matrix[dates[i]:dates[i]], irr_matrix[dates[i]:dates[i]])

# %%
i = 0

m = np.linspace(0.1, 30, 300)
plt.figure(figsize = (15, 7.5))
plt.title(dates[i].date())
plt.plot(m, ns(m, bfgs_recurrent[dates[i]:dates[i]].values[0]), label = 'L-BFGS-B')
plt.plot(m, ns(m, nelder_mead_recurrent[dates[i]:dates[i]].values[0]), label = 'Nelder-Mead')
plt.plot(m, ns(m, powell_recurrent[dates[i]:dates[i]].values[0]), label = 'Powell')
plt.plot(m, ns(m, trust_constr_recurrent[dates[i]:dates[i]].values[0]), label = 'Trust Constr')
plt.plot(m, ns(m, moex_thetas[dates[i]:dates[i]].values[0]), label = 'MOEX')
plt.scatter(maturity_matrix[dates[i]:dates[i]], irr_matrix[dates[i]:dates[i]])
plt.grid()
plt.legend()
#plt.scatter(maturity_matrix[dates[i]:dates[i]], irr_matrix[dates[i]:dates[i]])

# %%
i = 100

m = np.linspace(0.1, 30, 300)
plt.figure(figsize = (15, 7.5))
plt.title(dates[i].date())
plt.plot(m, ns(m, bfgs_recurrent[dates[i]:dates[i]].values[0]), label = 'L-BFGS-B')
plt.plot(m, ns(m, nelder_mead_recurrent[dates[i]:dates[i]].values[0]), label = 'Nelder-Mead')
plt.plot(m, ns(m, powell_recurrent[dates[i]:dates[i]].values[0]), label = 'Powell')
plt.plot(m, ns(m, trust_constr_recurrent[dates[i]:dates[i]].values[0]), label = 'Trust Constr')
plt.plot(m, ns(m, moex_thetas[dates[i]:dates[i]].values[0]), label = 'MOEX')
plt.scatter(maturity_matrix[dates[i]:dates[i]], irr_matrix[dates[i]:dates[i]])
plt.grid()
plt.legend()
#plt.scatter(maturity_matrix[dates[i]:dates[i]], irr_matrix[dates[i]:dates[i]])

# %%
i = 300

m = np.linspace(0.1, 30, 300)
plt.figure(figsize = (15, 7.5))
plt.title(dates[i].date())
plt.plot(m, ns(m, bfgs_recurrent[dates[i]:dates[i]].values[0]), label = 'L-BFGS-B')
plt.plot(m, ns(m, nelder_mead_recurrent[dates[i]:dates[i]].values[0]), label = 'Nelder-Mead')
plt.plot(m, ns(m, powell_recurrent[dates[i]:dates[i]].values[0]), label = 'Powell')
plt.plot(m, ns(m, trust_constr_recurrent[dates[i]:dates[i]].values[0]), label = 'Trust Constr')
plt.plot(m, ns(m, moex_thetas[dates[i]:dates[i]].values[0]), label = 'MOEX')
plt.scatter(maturity_matrix[dates[i]:dates[i]], irr_matrix[dates[i]:dates[i]])
plt.grid()
plt.legend()
#plt.scatter(maturity_matrix[dates[i]:dates[i]], irr_matrix[dates[i]:dates[i]])

# %%
i = 400

m = np.linspace(0.1, 30, 300)
plt.figure(figsize = (15, 7.5))
plt.title(dates[i].date())
plt.plot(m, ns(m, bfgs_recurrent[dates[i]:dates[i]].values[0]), label = 'L-BFGS-B')
plt.plot(m, ns(m, nelder_mead_recurrent[dates[i]:dates[i]].values[0]), label = 'Nelder-Mead')
plt.plot(m, ns(m, powell_recurrent[dates[i]:dates[i]].values[0]), label = 'Powell')
plt.plot(m, ns(m, trust_constr_recurrent[dates[i]:dates[i]].values[0]), label = 'Trust Constr')
plt.plot(m, ns(m, moex_thetas[dates[i]:dates[i]].values[0]), label = 'MOEX')
plt.scatter(maturity_matrix[dates[i]:dates[i]], irr_matrix[dates[i]:dates[i]])
plt.grid()
plt.legend()
#plt.scatter(maturity_matrix[dates[i]:dates[i]], irr_matrix[dates[i]:dates[i]])

# %%
i = 600

m = np.linspace(0.1, 30, 300)
plt.figure(figsize = (15, 7.5))
plt.title(dates[i].date())
plt.plot(m, ns(m, bfgs_recurrent[dates[i]:dates[i]].values[0]), label = 'L-BFGS-B')
plt.plot(m, ns(m, nelder_mead_recurrent[dates[i]:dates[i]].values[0]), label = 'Nelder-Mead')
plt.plot(m, ns(m, powell_recurrent[dates[i]:dates[i]].values[0]), label = 'Powell')
plt.plot(m, ns(m, trust_constr_recurrent[dates[i]:dates[i]].values[0]), label = 'Trust Constr')
plt.plot(m, ns(m, moex_thetas[dates[i]:dates[i]].values[0]), label = 'MOEX')
plt.scatter(maturity_matrix[dates[i]:dates[i]], irr_matrix[dates[i]:dates[i]])
plt.grid()
plt.legend()
#plt.scatter(maturity_matrix[dates[i]:dates[i]], irr_matrix[dates[i]:dates[i]])

# %%
i = 800

m = np.linspace(0.1, 30, 300)
plt.figure(figsize = (15, 7.5))
plt.title(dates[i].date())
plt.plot(m, ns(m, bfgs_recurrent[dates[i]:dates[i]].values[0]), label = 'L-BFGS-B')
plt.plot(m, ns(m, nelder_mead_recurrent[dates[i]:dates[i]].values[0]), label = 'Nelder-Mead')
plt.plot(m, ns(m, powell_recurrent[dates[i]:dates[i]].values[0]), label = 'Powell')
plt.plot(m, ns(m, trust_constr_recurrent[dates[i]:dates[i]].values[0]), label = 'Trust Constr')
plt.plot(m, ns(m, moex_thetas[dates[i]:dates[i]].values[0]), label = 'MOEX')
plt.scatter(maturity_matrix[dates[i]:dates[i]], irr_matrix[dates[i]:dates[i]])
plt.grid()
plt.legend()
#plt.scatter(maturity_matrix[dates[i]:dates[i]], irr_matrix[dates[i]:dates[i]])

# %%
i = 1000

m = np.linspace(0.1, 30, 300)
plt.figure(figsize = (15, 7.5))
plt.title(dates[i].date())
plt.plot(m, ns(m, bfgs_recurrent[dates[i]:dates[i]].values[0]), label = 'L-BFGS-B')
plt.plot(m, ns(m, nelder_mead_recurrent[dates[i]:dates[i]].values[0]), label = 'Nelder-Mead')
plt.plot(m, ns(m, powell_recurrent[dates[i]:dates[i]].values[0]), label = 'Powell')
plt.plot(m, ns(m, trust_constr_recurrent[dates[i]:dates[i]].values[0]), label = 'Trust Constr')
plt.plot(m, ns(m, moex_thetas[dates[i]:dates[i]].values[0]), label = 'MOEX')
plt.scatter(maturity_matrix[dates[i]:dates[i]], irr_matrix[dates[i]:dates[i]])
plt.grid()
plt.legend()
#plt.scatter(maturity_matrix[dates[i]:dates[i]], irr_matrix[dates[i]:dates[i]])
