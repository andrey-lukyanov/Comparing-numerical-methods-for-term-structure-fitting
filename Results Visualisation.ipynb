# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from thesis_library import *
pd.options.display.max_rows = 999

# %% [markdown]
# # Thetas import

# %% [markdown]
# ## Random

# %%
bfgs_rand1 = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Thetas/bfgs_rand_1.csv', index_col='TRADEDATE', parse_dates = True)
bfgs_rand2 = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Thetas/bfgs_rand_2.csv', index_col='TRADEDATE', parse_dates = True)
bfgs_rand3 = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Thetas/bfgs_rand_3.csv', index_col='TRADEDATE', parse_dates = True)
bfgs_rand4 = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Thetas/bfgs_rand_4.csv', index_col='TRADEDATE', parse_dates = True)
bfgs_rand5 = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Thetas/bfgs_rand_5.csv', index_col='TRADEDATE', parse_dates = True)
bfgs_rand6 = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Thetas/bfgs_rand_6.csv', index_col='TRADEDATE', parse_dates = True)
bfgs_rand7 = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Thetas/bfgs_rand_7.csv', index_col='TRADEDATE', parse_dates = True)
bfgs_rand8 = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Thetas/bfgs_rand_8.csv', index_col='TRADEDATE', parse_dates = True)
bfgs_rand9 = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Thetas/bfgs_rand_9.csv', index_col='TRADEDATE', parse_dates = True)
bfgs_rand10 = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Thetas/bfgs_rand_10.csv', index_col='TRADEDATE', parse_dates = True)
bfgs_rand11 = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Thetas/bfgs_rand_11.csv', index_col='TRADEDATE', parse_dates = True)
bfgs_rand12 = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Thetas/bfgs_rand_12.csv', index_col='TRADEDATE', parse_dates = True)
bfgs_rand13 = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Thetas/bfgs_rand_13.csv', index_col='TRADEDATE', parse_dates = True)
bfgs_rand14 = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Thetas/bfgs_rand_14.csv', index_col='TRADEDATE', parse_dates = True)
bfgs_rand15 = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Thetas/bfgs_rand_15.csv', index_col='TRADEDATE', parse_dates = True)
bfgs_rand16 = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Thetas/bfgs_rand_16.csv', index_col='TRADEDATE', parse_dates = True)

gauss_newton_rand1 = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Thetas/gauss_newton_rand_1.csv', index_col='TRADEDATE', parse_dates = True)
gauss_newton_rand2 = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Thetas/gauss_newton_rand_2.csv', index_col='TRADEDATE', parse_dates = True)
gauss_newton_rand3 = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Thetas/gauss_newton_rand_3.csv', index_col='TRADEDATE', parse_dates = True)
gauss_newton_rand4 = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Thetas/gauss_newton_rand_4.csv', index_col='TRADEDATE', parse_dates = True)
gauss_newton_rand5 = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Thetas/gauss_newton_rand_5.csv', index_col='TRADEDATE', parse_dates = True)
gauss_newton_rand6 = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Thetas/gauss_newton_rand_6.csv', index_col='TRADEDATE', parse_dates = True)
gauss_newton_rand7 = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Thetas/gauss_newton_rand_7.csv', index_col='TRADEDATE', parse_dates = True)
gauss_newton_rand8 = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Thetas/gauss_newton_rand_8.csv', index_col='TRADEDATE', parse_dates = True)
gauss_newton_rand9 = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Thetas/gauss_newton_rand_9.csv', index_col='TRADEDATE', parse_dates = True)
gauss_newton_rand10 = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Thetas/gauss_newton_rand_10.csv', index_col='TRADEDATE', parse_dates = True)
gauss_newton_rand11 = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Thetas/gauss_newton_rand_11.csv', index_col='TRADEDATE', parse_dates = True)
gauss_newton_rand12 = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Thetas/gauss_newton_rand_12.csv', index_col='TRADEDATE', parse_dates = True)
gauss_newton_rand13 = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Thetas/gauss_newton_rand_13.csv', index_col='TRADEDATE', parse_dates = True)
gauss_newton_rand14 = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Thetas/gauss_newton_rand_14.csv', index_col='TRADEDATE', parse_dates = True)
gauss_newton_rand15 = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Thetas/gauss_newton_rand_15.csv', index_col='TRADEDATE', parse_dates = True)
gauss_newton_rand16 = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Thetas/gauss_newton_rand_16.csv', index_col='TRADEDATE', parse_dates = True)

nelder_mead_rand1 = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Thetas/nelder_mead_rand_1.csv', index_col='TRADEDATE', parse_dates = True)
nelder_mead_rand2 = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Thetas/nelder_mead_rand_2.csv', index_col='TRADEDATE', parse_dates = True)
nelder_mead_rand3 = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Thetas/nelder_mead_rand_3.csv', index_col='TRADEDATE', parse_dates = True)
nelder_mead_rand4 = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Thetas/nelder_mead_rand_4.csv', index_col='TRADEDATE', parse_dates = True)
nelder_mead_rand5 = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Thetas/nelder_mead_rand_5.csv', index_col='TRADEDATE', parse_dates = True)
nelder_mead_rand6 = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Thetas/nelder_mead_rand_6.csv', index_col='TRADEDATE', parse_dates = True)
nelder_mead_rand7 = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Thetas/nelder_mead_rand_7.csv', index_col='TRADEDATE', parse_dates = True)
nelder_mead_rand8 = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Thetas/nelder_mead_rand_8.csv', index_col='TRADEDATE', parse_dates = True)
nelder_mead_rand9 = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Thetas/nelder_mead_rand_9.csv', index_col='TRADEDATE', parse_dates = True)
nelder_mead_rand10 = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Thetas/nelder_mead_rand_10.csv', index_col='TRADEDATE', parse_dates = True)
nelder_mead_rand11 = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Thetas/nelder_mead_rand_11.csv', index_col='TRADEDATE', parse_dates = True)
nelder_mead_rand12 = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Thetas/nelder_mead_rand_12.csv', index_col='TRADEDATE', parse_dates = True)
nelder_mead_rand13 = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Thetas/nelder_mead_rand_13.csv', index_col='TRADEDATE', parse_dates = True)
nelder_mead_rand14 = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Thetas/nelder_mead_rand_14.csv', index_col='TRADEDATE', parse_dates = True)
nelder_mead_rand15 = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Thetas/nelder_mead_rand_15.csv', index_col='TRADEDATE', parse_dates = True)
nelder_mead_rand16 = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Thetas/nelder_mead_rand_16.csv', index_col='TRADEDATE', parse_dates = True)

powell_rand1 = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Thetas/powell_rand_1.csv', index_col='TRADEDATE', parse_dates = True)
powell_rand2 = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Thetas/powell_rand_2.csv', index_col='TRADEDATE', parse_dates = True)
powell_rand3 = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Thetas/powell_rand_3.csv', index_col='TRADEDATE', parse_dates = True)
powell_rand4 = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Thetas/powell_rand_4.csv', index_col='TRADEDATE', parse_dates = True)
powell_rand5 = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Thetas/powell_rand_5.csv', index_col='TRADEDATE', parse_dates = True)
powell_rand6 = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Thetas/powell_rand_6.csv', index_col='TRADEDATE', parse_dates = True)
powell_rand7 = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Thetas/powell_rand_7.csv', index_col='TRADEDATE', parse_dates = True)
powell_rand8 = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Thetas/powell_rand_8.csv', index_col='TRADEDATE', parse_dates = True)
powell_rand9 = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Thetas/powell_rand_9.csv', index_col='TRADEDATE', parse_dates = True)
powell_rand10 = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Thetas/powell_rand_10.csv', index_col='TRADEDATE', parse_dates = True)
powell_rand11 = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Thetas/powell_rand_11.csv', index_col='TRADEDATE', parse_dates = True)
powell_rand12 = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Thetas/powell_rand_12.csv', index_col='TRADEDATE', parse_dates = True)
powell_rand13 = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Thetas/powell_rand_13.csv', index_col='TRADEDATE', parse_dates = True)
powell_rand14 = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Thetas/powell_rand_14.csv', index_col='TRADEDATE', parse_dates = True)
powell_rand15 = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Thetas/powell_rand_15.csv', index_col='TRADEDATE', parse_dates = True)
powell_rand16 = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Thetas/powell_rand_16.csv', index_col='TRADEDATE', parse_dates = True)

# %% [markdown]
# ## Recurrent

# %%
bfgs_recurrent = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Thetas/bfgs_recurrent.csv', index_col='TRADEDATE', parse_dates = True)
gauss_newton_recurrent = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Thetas/gauss_newton_recurrent.csv', index_col='TRADEDATE', parse_dates = True)
nelder_mead_recurrent = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Thetas/nelder_mead_recurrent.csv', index_col='TRADEDATE', parse_dates = True)
powell_recurrent = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Thetas/powell_recurrent.csv', index_col='TRADEDATE', parse_dates = True)

# %% [markdown]
# ## PSO

# %%
pso_batch_62 = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Thetas/pso_batch_62.csv', index_col='TRADEDATE', parse_dates = True)
pso_batch_126 = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Thetas/pso_batch_126.csv', index_col='TRADEDATE', parse_dates = True)
pso_batch_189 = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Thetas/pso_batch_189.csv', index_col='TRADEDATE', parse_dates = True)
pso_batch_252 = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Thetas/pso_batch_252.csv', index_col='TRADEDATE', parse_dates = True)

# %%
pso_df = pd.concat([pso_batch_62, pso_batch_126, pso_batch_189, pso_batch_252])

# %%
pso_df.to_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Thetas/pso_df.csv')

# %% [markdown]
# ## Flat rate

# %%
bfgs_flat_rate = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Thetas/bfgs_flat_rate.csv', index_col='TRADEDATE', parse_dates = True)
gauss_newton_flat_rate = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Thetas/gauss_newton_flat_rate.csv', index_col='TRADEDATE', parse_dates = True)
nelder_mead_flat_rate = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Thetas/nelder_mead_flat_rate.csv', index_col='TRADEDATE', parse_dates = True)
powell_flat_rate = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Thetas/powell_flat_rate.csv', index_col='TRADEDATE', parse_dates = True)

# %% [markdown]
# ## Diebold Li

# %%
bfgs_diebold_li = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Thetas/bfgs_diebold_li.csv', index_col='TRADEDATE', parse_dates = True)
gauss_newton_diebold_li = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Thetas/gauss_newton_diebold_li.csv', index_col='TRADEDATE', parse_dates = True)
nelder_mead_diebold_li = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Thetas/nelder_mead_diebold_li.csv', index_col='TRADEDATE', parse_dates = True)
powell_diebold_li = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Thetas/powell_diebold_li.csv', index_col='TRADEDATE', parse_dates = True)

# %% [markdown]
# ## CBR

# %%
cbr = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Thetas/cbr_thetas.csv', index_col='Dates', parse_dates = True)

# %% [markdown]
# ## Merger

# %%
results = [bfgs_rand1, bfgs_rand2, bfgs_rand3, bfgs_rand4, bfgs_rand5, bfgs_rand6, bfgs_rand7, bfgs_rand8, 
           bfgs_rand9, bfgs_rand10, bfgs_rand11, bfgs_rand12, bfgs_rand13, bfgs_rand14, bfgs_rand15, bfgs_rand16,
           gauss_newton_rand1, gauss_newton_rand2, gauss_newton_rand3, gauss_newton_rand4,
           gauss_newton_rand5, gauss_newton_rand6, gauss_newton_rand7, gauss_newton_rand8,
           gauss_newton_rand9, gauss_newton_rand10, gauss_newton_rand11, gauss_newton_rand12, 
           gauss_newton_rand13, gauss_newton_rand14, gauss_newton_rand15, gauss_newton_rand16,
           nelder_mead_rand1, nelder_mead_rand2, nelder_mead_rand3, nelder_mead_rand4, 
           nelder_mead_rand5, nelder_mead_rand6, nelder_mead_rand7, nelder_mead_rand8, 
           nelder_mead_rand9, nelder_mead_rand10, nelder_mead_rand11, nelder_mead_rand12, 
           nelder_mead_rand13, nelder_mead_rand14, nelder_mead_rand15, nelder_mead_rand16,
           powell_rand1, powell_rand2, powell_rand3, powell_rand4, 
           powell_rand5, powell_rand6, powell_rand7, powell_rand8, 
           powell_rand9, powell_rand10, powell_rand11, powell_rand12, 
           powell_rand13, powell_rand14, powell_rand15, powell_rand16, 
           bfgs_recurrent, gauss_newton_recurrent, nelder_mead_recurrent, powell_recurrent, 
           bfgs_flat_rate, gauss_newton_flat_rate, nelder_mead_flat_rate, powell_flat_rate,
           pso_df,
           bfgs_diebold_li, gauss_newton_diebold_li, nelder_mead_diebold_li, powell_diebold_li,           
           cbr]

# %%
results_names = ['bfgs_rand_1', 'bfgs_rand_2', 'bfgs_rand_3', 'bfgs_rand_4', 
                 'bfgs_rand_5', 'bfgs_rand_6', 'bfgs_rand_7', 'bfgs_rand_8',
                 'bfgs_rand_9', 'bfgs_rand_10', 'bfgs_rand_11', 'bfgs_rand_12',
                 'bfgs_rand_13', 'bfgs_rand_14', 'bfgs_rand_15', 'bfgs_rand_16',
                 'gauss_newton_rand1', 'gauss_newton_rand2', 'gauss_newton_rand3', 'gauss_newton_rand4', 
                 'gauss_newton_rand5', 'gauss_newton_rand6', 'gauss_newton_rand7', 'gauss_newton_rand8',
                 'gauss_newton_rand9', 'gauss_newton_rand10', 'gauss_newton_rand11', 'gauss_newton_rand12', 
                 'gauss_newton_rand13', 'gauss_newton_rand14', 'gauss_newton_rand15', 'gauss_newton_rand16',
                 'nelder_mead_rand_1', 'nelder_mead_rand_2', 'nelder_mead_rand_3', 'nelder_mead_rand_4',
                 'nelder_mead_rand_5', 'nelder_mead_rand_6', 'nelder_mead_rand_7', 'nelder_mead_rand_8',
                 'nelder_mead_rand_9', 'nelder_mead_rand_10', 'nelder_mead_rand_11', 'nelder_mead_rand_12',
                 'nelder_mead_rand_13', 'nelder_mead_rand_14', 'nelder_mead_rand_15', 'nelder_mead_rand_16',
                 'powell_rand_1', 'powell_rand_2', 'powell_rand_3', 'powell_rand_4',
                 'powell_rand_5', 'powell_rand_6', 'powell_rand_7', 'powell_rand_8',
                 'powell_rand_9', 'powell_rand_10', 'powell_rand_11', 'powell_rand_12',
                 'powell_rand_13', 'powell_rand_14', 'powell_rand_15', 'powell_rand_16',
                 'bfgs_recurrent', 'gauss_newton_recurrent', 'nelder_mead_recurrent', 'powell_recurrent', 
                 'bfgs_flat_rate', 'gauss_newton_flat_rate', 'nelder_mead_flat_rate', 'powell_flat_rate',
                 'pso_df', 
                 'bfgs_diebold_li', 'gauss_newton_diebold_li', 'nelder_mead_diebold_li', 'powell_diebold_li',
                 'cbr']

# %%
bfgs_indicies = list(range(0, 16)) + [-14, -10, -5]
gauss_newton_indicies = list(range(16, 32)) + [-13, -19, -4]
nelder_mead_indicies = list(range(32, 48)) + [-12, -18, -3]
powell_indicies = list(range(48, 64)) + [-11, -17, -2]

# %%
bfgs_names_list = ['bfgs_rand_1', 'bfgs_rand_2','bfgs_rand_3', 'bfgs_rand_4','bfgs_rand_5', 'bfgs_rand_6',
                   'bfgs_rand_7', 'bfgs_rand_8','bfgs_rand_9', 'bfgs_rand_10', 'bfgs_rand_11', 'bfgs_rand_12', 
                   'bfgs_rand_13', 'bfgs_rand_14', 'bfgs_rand_15', 'bfgs_rand_16','bfgs_recurrent', 'bfgs_flat_rate', 
                   'bfgs_diebold_li']
gauss_newton_names_list = ['gauss_newton_rand1', 'gauss_newton_rand2', 'gauss_newton_rand3', 'gauss_newton_rand4',
                           'gauss_newton_rand5', 'gauss_newton_rand6', 'gauss_newton_rand7', 'gauss_newton_rand8',
                           'gauss_newton_rand9', 'gauss_newton_rand10', 'gauss_newton_rand11', 'gauss_newton_rand12', 
                           'gauss_newton_rand13', 'gauss_newton_rand14', 'gauss_newton_rand15', 'gauss_newton_rand16', 
                           'gauss_newton_recurrent', 'gauss_newton_flat_rate', 'gauss_newton_diebold_li']
nelder_mead_names_list = ['nelder_mead_rand_1', 'nelder_mead_rand_2', 'nelder_mead_rand_3', 'nelder_mead_rand_4', 
                          'nelder_mead_rand_5', 'nelder_mead_rand_6', 'nelder_mead_rand_7', 'nelder_mead_rand_8',
                          'nelder_mead_rand_9', 'nelder_mead_rand_10', 'nelder_mead_rand_11', 'nelder_mead_rand_12',
                          'nelder_mead_rand_13', 'nelder_mead_rand_14', 'nelder_mead_rand_15', 'nelder_mead_rand_16',
                          'nelder_mead_recurrent', 'nelder_mead_flat_rate', 'nelder_mead_diebold_li']
powel_names_list = ['powell_rand_1', 'powell_rand_2', 'powell_rand_3', 'powell_rand_4', 'powell_rand_5', 'powell_rand_6', 
                    'powell_rand_7', 'powell_rand_8', 'powell_rand_9', 'powell_rand_10', 'powell_rand_11', 
                    'powell_rand_12', 'powell_rand_13', 'powell_rand_14', 'powell_rand_15', 'powell_rand_16', 
                    'powell_recurrent', 'powell_flat_rate', 'powell_diebold_li']

# %% [markdown]
# # Comparison

# %% [markdown]
# ## Loss function values

# %%
# %%time

loss_function_values_df = pd.DataFrame(data = np.zeros([252, len(results_names)]), columns = results_names, index = dates)

for i in range(len(dates)):
    
    loss_func = build_ss_loss_function(date = dates[i], theta_lb = 0.1, theta_rb = 30)
    
    for j in range(len(results_names)):
        
        loss_function_values_df.iloc[i, j] = loss_func(results[j].values[i])
# Out:
# /Users/andrey_lukyanov/anaconda3/lib/python3.7/site-packages/pandas/core/series.py:679: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/thesis_library.py:70: RuntimeWarning: overflow encountered in square
#   J = (((np.array(result_df['Discounted']) - np.array(result_df['Market prices']))/1000)**2).sum()
# CPU times: user 3min 56s, sys: 1.18 s, total: 3min 57s
# Wall time: 4min 2s

# %%
loss_function_values_df.to_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/4.1/loss_function_values.csv')

# %%
loss_function_values_df = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/4.1/loss_function_values.csv', index_col='TRADEDATE', parse_dates = True)

# %%
# %%bash
# say finished

# %%
plt.figure(figsize = (15,7.5))
plt.plot(loss_function_values_df[['bfgs_rand_1', 'bfgs_rand_2',
                                  'bfgs_rand_3', 'bfgs_rand_4',
                                  'bfgs_rand_5', 'bfgs_rand_6',
                                  'bfgs_rand_7', 'bfgs_rand_8',
                                  'bfgs_rand_9', 'bfgs_rand_10', 
                                  'bfgs_rand_11', 'bfgs_rand_12', 
                                  'bfgs_rand_13', 'bfgs_rand_14', 
                                  'bfgs_rand_15', 'bfgs_rand_16',
                                  'bfgs_recurrent', 'bfgs_flat_rate', 
                                  'bfgs_diebold_li']].max(axis=1), label = 'Max BFGS')
plt.plot(loss_function_values_df[['bfgs_rand_1', 'bfgs_rand_2',
                                  'bfgs_rand_3', 'bfgs_rand_4',
                                  'bfgs_rand_5', 'bfgs_rand_6',
                                  'bfgs_rand_7', 'bfgs_rand_8',
                                  'bfgs_rand_9', 'bfgs_rand_10', 
                                  'bfgs_rand_11', 'bfgs_rand_12', 
                                  'bfgs_rand_13', 'bfgs_rand_14', 
                                  'bfgs_rand_15', 'bfgs_rand_16',
                                  'bfgs_recurrent', 'bfgs_flat_rate', 
                                  'bfgs_diebold_li']].min(axis=1), label = 'Min BFGS')
                 
                
plt.plot(loss_function_values_df[['gauss_newton_rand1', 'gauss_newton_rand2', 
                                  'gauss_newton_rand3', 'gauss_newton_rand4',
                                  'gauss_newton_rand5', 'gauss_newton_rand6', 
                                  'gauss_newton_rand7', 'gauss_newton_rand8',
                                  'gauss_newton_rand9', 'gauss_newton_rand10', 
                                  'gauss_newton_rand11', 'gauss_newton_rand12', 
                                  'gauss_newton_rand13', 'gauss_newton_rand14', 
                                  'gauss_newton_rand15', 'gauss_newton_rand16',
                                  'gauss_newton_recurrent', 'gauss_newton_flat_rate',
                                  'gauss_newton_diebold_li']].max(axis=1), label = 'Max Gauss-Newton')
plt.plot(loss_function_values_df[['gauss_newton_rand1', 'gauss_newton_rand2', 
                                  'gauss_newton_rand3', 'gauss_newton_rand4',
                                  'gauss_newton_rand5', 'gauss_newton_rand6',
                                  'gauss_newton_rand7', 'gauss_newton_rand8',
                                  'gauss_newton_rand9', 'gauss_newton_rand10', 
                                  'gauss_newton_rand11', 'gauss_newton_rand12', 
                                  'gauss_newton_rand13', 'gauss_newton_rand14', 
                                  'gauss_newton_rand15', 'gauss_newton_rand16',
                                  'gauss_newton_recurrent', 'gauss_newton_flat_rate',
                                  'gauss_newton_diebold_li']].min(axis=1), label = 'Min Gauss-Newton')

plt.plot(loss_function_values_df[['nelder_mead_rand_1', 'nelder_mead_rand_2',
                                  'nelder_mead_rand_3', 'nelder_mead_rand_4',
                                  'nelder_mead_rand_5', 'nelder_mead_rand_6',
                                  'nelder_mead_rand_7', 'nelder_mead_rand_8',
                                  'nelder_mead_rand_9', 'nelder_mead_rand_10', 
                                  'nelder_mead_rand_11', 'nelder_mead_rand_12',
                                  'nelder_mead_rand_13', 'nelder_mead_rand_14', 
                                  'nelder_mead_rand_15', 'nelder_mead_rand_16',
                                  'nelder_mead_recurrent', 'nelder_mead_flat_rate',
                                  'nelder_mead_diebold_li']].max(axis = 1), label = 'Max Nelder-Mead')
plt.plot(loss_function_values_df[['nelder_mead_rand_1', 'nelder_mead_rand_2',
                                  'nelder_mead_rand_3', 'nelder_mead_rand_4',
                                  'nelder_mead_rand_5', 'nelder_mead_rand_6',
                                  'nelder_mead_rand_7', 'nelder_mead_rand_8',
                                  'nelder_mead_rand_9', 'nelder_mead_rand_10', 
                                  'nelder_mead_rand_11', 'nelder_mead_rand_12',
                                  'nelder_mead_rand_13', 'nelder_mead_rand_14', 
                                  'nelder_mead_rand_15', 'nelder_mead_rand_16',
                                  'nelder_mead_recurrent', 'nelder_mead_flat_rate', 
                                  'nelder_mead_diebold_li']].min(axis = 1), label = 'Min Nelder-Mead')

#plt.plot(loss_function_values_df[['powell_rand_1', 'powell_rand_2',
#                                  'powell_rand_3', 'powell_rand_4',
#                                  'powell_rand_5', 'powell_rand_6',
#                                  'powell_rand_7', 'powell_rand_8',
#                                  'powell_rand_9', 'powell_rand_10', 
#                                  'powell_rand_11', 'powell_rand_12', 
#                                  'powell_rand_13', 'powell_rand_14', 
#                                  'powell_rand_15', 'powell_rand_16',
#                                  'powell_recurrent', 'powell_flat_rate',
#                                  'powell_diebold_li']].max(axis = 1), label = 'Max Powell')
plt.plot(loss_function_values_df[['powell_rand_1', 'powell_rand_2',
                                  'powell_rand_3', 'powell_rand_4',
                                  'powell_rand_5', 'powell_rand_6',
                                  'powell_rand_7', 'powell_rand_8',
                                  'powell_rand_9', 'powell_rand_10', 
                                  'powell_rand_11', 'powell_rand_12', 
                                  'powell_rand_13', 'powell_rand_14', 
                                  'powell_rand_15', 'powell_rand_16',
                                  'powell_recurrent', 'powell_flat_rate',
                                  'powell_diebold_li']].min(axis = 1), label = 'Min Powell')

plt.plot(loss_function_values_df['pso_df'], label = 'PSO')
plt.xlabel('Date', fontsize = 24)
plt.ylabel('Loss', fontsize = 24)
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
plt.legend(fontsize = 14, loc = 1)
plt.title('Min/Max Loss', fontsize = 24);

# %%
plt.figure(figsize = (15,7.5))
plt.title('Log of mean loss on random weights', fontsize = 24)
plt.plot(np.log(loss_function_values_df.mean()[0:16].values), label = 'BFGS')
plt.plot(np.log(loss_function_values_df.mean()[16:32].values), label = 'Gauss-Newton')
plt.plot(np.log(loss_function_values_df.mean()[32:48].values), label = 'Nelder-Mead')
#plt.plot(np.log(loss_function_values_df.mean()[48:64].values), label = 'Powell')
plt.xlabel('Random weight', fontsize = 24)
plt.ylabel('Log of mean RMSE', fontsize = 24)
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
plt.legend(fontsize = 14);
plt.savefig('Pictures/RMSE_random.png')

# %%
figure, axes = plt.subplots(nrows=2, ncols=2,figsize=(15, 10))

axes[0, 0].plot(loss_function_values_df[['bfgs_rand_1', 'bfgs_rand_2',
                                  'bfgs_rand_3', 'bfgs_rand_4',
                                  'bfgs_rand_5', 'bfgs_rand_6',
                                  'bfgs_rand_7', 'bfgs_rand_8',
                                  'bfgs_rand_9', 'bfgs_rand_10', 
                                  'bfgs_rand_11', 'bfgs_rand_12', 
                                  'bfgs_rand_13', 'bfgs_rand_14', 
                                  'bfgs_rand_15', 'bfgs_rand_16']].mean(axis = 1), label = 'Mean of random')

axes[0, 0].plot(loss_function_values_df[['bfgs_flat_rate']], label = 'Flat rate')
axes[0, 0].plot(loss_function_values_df[['bfgs_recurrent']], label = 'Recurrent')
#axes[0, 0].plot(loss_function_values_df[['bfgs_diebold_li']], label = 'Diebold, Li')

axes[0, 0].set_xlabel('Date', fontsize = 14)
axes[0, 0].set_ylabel('Loss', fontsize = 14)
axes[0, 0].tick_params(axis='both', which='major', labelsize=12)
#axes[0, 0].set_ylim(0, 0.0009)
axes[0, 0].legend(fontsize = 14, loc = 1)
axes[0, 0].set_title('BFGS Loss', size=24);


axes[0, 1].plot(loss_function_values_df[['gauss_newton_rand1', 'gauss_newton_rand2', 
                                         'gauss_newton_rand3', 'gauss_newton_rand4',
                                         'gauss_newton_rand5', 'gauss_newton_rand6',
                                         'gauss_newton_rand7', 'gauss_newton_rand8',
                                         'gauss_newton_rand9', 'gauss_newton_rand10',
                                         'gauss_newton_rand11', 'gauss_newton_rand12',
                                         'gauss_newton_rand13', 'gauss_newton_rand14',
                                         'gauss_newton_rand15', 'gauss_newton_rand16']].mean(axis = 1), label = 'Mean of random')

axes[0, 1].plot(loss_function_values_df[['gauss_newton_flat_rate']], label = 'Flat rate')
axes[0, 1].plot(loss_function_values_df[['gauss_newton_recurrent']], label = 'Recurrent')
axes[0, 1].plot(loss_function_values_df[['gauss_newton_diebold_li']], label = 'Diebold, Li')

axes[0, 1].set_xlabel('Date', fontsize = 14)
axes[0, 1].set_ylabel('Loss', fontsize = 14)
axes[0, 1].tick_params(axis='both', which='major', labelsize=12)
#axes[0, 0].set_ylim(0, 0.0009)
axes[0, 1].legend(fontsize = 14, loc = 1)
axes[0, 1].set_title('Gauss-Newton Loss', size=24);




axes[1, 0].plot(loss_function_values_df[['nelder_mead_rand_1', 'nelder_mead_rand_2',
                                         'nelder_mead_rand_3', 'nelder_mead_rand_4',
                                         'nelder_mead_rand_5', 'nelder_mead_rand_6',
                                         'nelder_mead_rand_7', 'nelder_mead_rand_8',
                                         'nelder_mead_rand_9', 'nelder_mead_rand_10',
                                         'nelder_mead_rand_11', 'nelder_mead_rand_12',
                                         'nelder_mead_rand_13', 'nelder_mead_rand_14', 
                                         'nelder_mead_rand_15', 'nelder_mead_rand_16']].mean(axis = 1), label = 'Mean of random')

axes[1, 0].plot(loss_function_values_df[['nelder_mead_flat_rate']], label = 'Flat rate')
axes[1, 0].plot(loss_function_values_df[['nelder_mead_recurrent']], label = 'Recurrent')
axes[1, 0].plot(loss_function_values_df[['nelder_mead_diebold_li']], label = 'Diebold, Li')

axes[1, 0].set_xlabel('Date', fontsize = 14)
axes[1, 0].set_ylabel('Loss', fontsize = 14)
axes[1, 0].tick_params(axis='both', which='major', labelsize=12)
#axes[0, 0].set_ylim(0, 0.0009)
axes[1, 0].legend(fontsize = 14, loc = 1)
axes[1, 0].set_title('Nelder-Mead Loss', size=24);




axes[1, 1].plot(loss_function_values_df[['powell_flat_rate']], label = 'Flat rate')
#axes[1, 1].plot(loss_function_values_df[['powell_recurrent']], label = 'Recurrent')
axes[1, 1].plot(loss_function_values_df[['powell_diebold_li']], label = 'Diebold, Li')

axes[1, 1].set_xlabel('Date', fontsize = 14)
axes[1, 1].set_ylabel('Loss', fontsize = 14)
axes[1, 1].tick_params(axis='both', which='major', labelsize=12)
#axes[0, 0].set_ylim(0, 0.0009)
axes[1, 1].legend(fontsize = 14, loc = 1)
axes[1, 1].set_title('Powell Loss', size=24);

figure.tight_layout()
plt.savefig('Pictures/Loss.png')

# %% [markdown]
# # Times not converged

# %%
(loss_function_values_df > 0.001).sum()
# Out:
# bfgs_rand_1                  0
# bfgs_rand_2                  0
# bfgs_rand_3                  0
# bfgs_rand_4                  0
# bfgs_rand_5                  0
# bfgs_rand_6                  0
# bfgs_rand_7                  0
# bfgs_rand_8                  0
# bfgs_rand_9                  0
# bfgs_rand_10                 0
# bfgs_rand_11                 0
# bfgs_rand_12                 0
# bfgs_rand_13                 0
# bfgs_rand_14                 0
# bfgs_rand_15                 0
# bfgs_rand_16                 0
# gauss_newton_rand1           0
# gauss_newton_rand2           0
# gauss_newton_rand3           0
# gauss_newton_rand4           0
# gauss_newton_rand5         252
# gauss_newton_rand6           0
# gauss_newton_rand7           0
# gauss_newton_rand8           0
# gauss_newton_rand9           0
# gauss_newton_rand10          0
# gauss_newton_rand11          0
# gauss_newton_rand12          0
# gauss_newton_rand13          0
# gauss_newton_rand14          0
# ...

# %% [markdown]
# # RMSE

# %%
# %%time

rmse_df = pd.DataFrame(data = np.zeros([252, len(results_names)]), columns = results_names, index = dates)

for i in range(len(dates)):
    
    rmse_func = build_rmse_function(date = dates[i])
    
    for j in range(len(results_names)):
        
        rmse_df.iloc[i, j] = rmse_func(results[j].values[i])
        
rmse_df.to_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/RMSE/rmse.csv')
# Out:
# /Users/andrey_lukyanov/anaconda3/lib/python3.7/site-packages/pandas/core/series.py:679: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/thesis_library.py:165: RuntimeWarning: overflow encountered in square
#   J = (((np.array(result_df['Discounted']) - np.array(result_df['Market prices']))/1000)**2).sum()
# CPU times: user 3min 40s, sys: 343 ms, total: 3min 41s
# Wall time: 3min 41s

# %%
rmse_df = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/RMSE/rmse.csv', index_col='TRADEDATE', parse_dates = True)

# %%
figure, axes = plt.subplots(nrows=2, ncols=2,figsize=(15, 8))

axes[0, 0].plot(rmse_df[['bfgs_rand_1', 'bfgs_rand_2',
                                  'bfgs_rand_3', 'bfgs_rand_4',
                                  'bfgs_rand_5', 'bfgs_rand_6',
                                  'bfgs_rand_7', 'bfgs_rand_8',
                                  'bfgs_rand_9', 'bfgs_rand_10', 
                                  'bfgs_rand_11', 'bfgs_rand_12', 
                                  'bfgs_rand_13', 'bfgs_rand_14', 
                                  'bfgs_rand_15', 'bfgs_rand_16']].mean(axis = 1), label = 'Mean of random')

axes[0, 0].plot(rmse_df[['bfgs_flat_rate']], label = 'Flat rate')
axes[0, 0].plot(rmse_df[['bfgs_recurrent']], label = 'Recurrent')
axes[0, 0].plot(rmse_df[['bfgs_diebold_li']], label = 'Diebold, Li')

axes[0, 0].set_xlabel('Date', fontsize = 14)
axes[0, 0].set_ylabel('RMSE', fontsize = 14)
axes[0, 0].tick_params(axis='both', which='major', labelsize=12)
#axes[0, 0].set_ylim(0, 0.0009)
axes[0, 0].legend(fontsize = 14, loc = 1)
axes[0, 0].set_title('BFGS', size=24);
axes[0, 0].grid()

axes[0, 1].plot(rmse_df[['gauss_newton_rand1', 'gauss_newton_rand2', 
                                         'gauss_newton_rand3', 'gauss_newton_rand4',
                                         'gauss_newton_rand5', 'gauss_newton_rand6',
                                         'gauss_newton_rand7', 'gauss_newton_rand8',
                                         'gauss_newton_rand9', 'gauss_newton_rand10',
                                         'gauss_newton_rand11', 'gauss_newton_rand12',
                                         'gauss_newton_rand13', 'gauss_newton_rand14',
                                         'gauss_newton_rand15', 'gauss_newton_rand16']].mean(axis = 1), label = 'Mean of random')

axes[0, 1].plot(rmse_df[['gauss_newton_flat_rate']], label = 'Flat rate')
axes[0, 1].plot(rmse_df[['gauss_newton_recurrent']], label = 'Recurrent')
axes[0, 1].plot(rmse_df[['gauss_newton_diebold_li']], label = 'Diebold, Li')

axes[0, 1].set_xlabel('Date', fontsize = 14)
axes[0, 1].set_ylabel('RMSE', fontsize = 14)
axes[0, 1].tick_params(axis='both', which='major', labelsize=12)
axes[0, 1].set_ylim(0, 0.0009)
axes[0, 1].legend(fontsize = 14, loc = 1)
axes[0, 1].set_title('Gauss-Newton', size=24);
axes[0, 1].grid()



axes[1, 0].plot(rmse_df[['nelder_mead_rand_1', 'nelder_mead_rand_2',
                                         'nelder_mead_rand_3', 'nelder_mead_rand_4',
                                         'nelder_mead_rand_5', 'nelder_mead_rand_6',
                                         'nelder_mead_rand_7', 'nelder_mead_rand_8',
                                         'nelder_mead_rand_9', 'nelder_mead_rand_10',
                                         'nelder_mead_rand_11', 'nelder_mead_rand_12',
                                         'nelder_mead_rand_13', 'nelder_mead_rand_14', 
                                         'nelder_mead_rand_15', 'nelder_mead_rand_16']].mean(axis = 1), label = 'Mean of random')

axes[1, 0].plot(rmse_df[['nelder_mead_flat_rate']], label = 'Flat rate')
axes[1, 0].plot(rmse_df[['nelder_mead_recurrent']], label = 'Recurrent')
axes[1, 0].plot(rmse_df[['nelder_mead_diebold_li']], label = 'Diebold, Li')

axes[1, 0].set_xlabel('Date', fontsize = 14)
axes[1, 0].set_ylabel('RMSE', fontsize = 14)
axes[1, 0].tick_params(axis='both', which='major', labelsize=12)
#axes[0, 0].set_ylim(0, 0.0009)
axes[1, 0].legend(fontsize = 14, loc = 1)
axes[1, 0].set_title('Nelder-Mead', size=24)
axes[1, 0].grid()

axes[1, 1].plot(rmse_df[['powell_rand_1', 'powell_rand_2',
                         'powell_rand_3', 'powell_rand_4',
                         'powell_rand_5', 'powell_rand_6',
                         'powell_rand_7', 'powell_rand_8',
                         'powell_rand_9', 'powell_rand_10', 
                         'powell_rand_11', 'powell_rand_12',
                         'powell_rand_13', 'powell_rand_14',
                         'powell_rand_15', 'powell_rand_16',]].mean(axis = 1), label = 'Mean of random')
axes[1, 1].plot(rmse_df[['powell_flat_rate']], label = 'Flat rate')
axes[1, 1].plot(rmse_df[['powell_recurrent']], label = 'Recurrent')
axes[1, 1].plot(rmse_df[['powell_diebold_li']], label = 'Diebold, Li')

axes[1, 1].set_xlabel('Date', fontsize = 14)
axes[1, 1].set_ylabel('RMSE', fontsize = 14)
axes[1, 1].tick_params(axis='both', which='major', labelsize=12)
axes[1, 1].set_ylim(0, 0.2)
axes[1, 1].legend(fontsize = 14, loc = 1)
axes[1, 1].set_title('Powell', size=24);
axes[1, 1].grid()

figure.tight_layout()
plt.savefig('Pictures/RMSE_presentation.png')

# %%
plt.figure(figsize = (15,7.5))
plt.title('Log of mean RMSE on random weights', fontsize = 24)
plt.plot(np.log(rmse_df[results_names[0:16]].mean(axis = 0).values), label = 'BFGS')
plt.plot(np.log(rmse_df[results_names[16:32]].mean(axis = 0).values), label = 'Gauss-Newton')
plt.plot(np.log(rmse_df[results_names[32:48]].mean(axis = 0).values), label = 'Nelder-Mead')
plt.plot(np.log(rmse_df[results_names[48:64]][rmse_df[results_names[48:64]] < 100000].mean(axis = 0).values), label = 'Powell')
plt.xlabel('Random weight', fontsize = 24)
plt.ylabel('Log of mean RMSE', fontsize = 24)
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
plt.legend(fontsize = 14);
plt.savefig('Pictures/RMSE_random.png')

# %% [markdown]
# # Hypothetical bonds prices calculation

# %%
short_bond_dates = np.linspace(0.5, 3, 6)
short_bond_payments = np.ones(6) * 4
short_bond_payments[-1] += 100

medium_bond_dates = np.linspace(0.5, 10, 20)
medium_bond_payments = np.ones(20) * 5
medium_bond_payments[-1] += 100

long_bond_dates = np.linspace(0.5, 30, 60)
long_bond_payments = np.ones(60) * 6
long_bond_payments[-1] += 100

# %%
# %%time

for q in range(len(results)):
        
    bonds_prices_df = pd.DataFrame(columns = ['short', 'medium', 'long'], data = np.zeros([252, 3]), index = bonds_prices.index)
    
    for j in range(3):
        
        for i in range(252):
            if j == 0:
                dcf = short_bond_payments * np.exp(- short_bond_dates * nss(m = short_bond_dates, theta = np.array(results[q].iloc[i]))/100)
                
            elif j == 1:
                dcf = medium_bond_payments * np.exp(- medium_bond_dates * nss(m = medium_bond_dates, theta = np.array(results[q].iloc[i]))/100)
                
            elif j == 2:
                dcf = long_bond_payments * np.exp(- long_bond_dates * nss(m = long_bond_dates, theta = np.array(results[q].iloc[i]))/100)
                
            bonds_prices_df.iloc[i, j] = dcf.sum()
        
    bonds_prices_df.to_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/1.3/' + results_names[q] + '.csv')
# Out:
# /Users/andrey_lukyanov/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: RuntimeWarning: overflow encountered in exp
#   if __name__ == '__main__':
# /Users/andrey_lukyanov/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: RuntimeWarning: overflow encountered in exp
#   if sys.path[0] == '':
# /Users/andrey_lukyanov/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:15: RuntimeWarning: overflow encountered in exp
#   from ipykernel import kernelapp as app
# /Users/andrey_lukyanov/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: RuntimeWarning: overflow encountered in multiply
#   if sys.path[0] == '':
# /Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/thesis_library.py:31: RuntimeWarning: overflow encountered in exp
# ...

# %%
hypothetical_bonds_prices = []

for result_name in results_names:
    hypothetical_bonds_prices.append(pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/1.3/' + result_name + '.csv', index_col='TRADEDATE', parse_dates=True))

# %%
figure, axes = plt.subplots(nrows=3, ncols=2,figsize=(15, 20))

#BFGS bonds
axes[0, 0].plot(hypothetical_bonds_prices[0]['short'], label = 'Random 1')
axes[0, 0].plot(hypothetical_bonds_prices[1]['short'], label = 'Random 2')
axes[0, 0].plot(hypothetical_bonds_prices[2]['short'], label = 'Random 3')
axes[0, 0].plot(hypothetical_bonds_prices[3]['short'], label = 'Random 4')
axes[0, 0].plot(hypothetical_bonds_prices[-14]['short'], label = 'recurrent')
axes[0, 0].plot(hypothetical_bonds_prices[-10]['short'], label = 'flat', linewidth=2.0)
#axes[0, 0].plot(hypothetical_bonds_prices[-5]['short'], label = 'Diebold, Li')
axes[0, 0].set_xlabel('Date', fontsize = 14)
axes[0, 0].set_ylabel('Price', fontsize = 14)
axes[0, 0].tick_params(axis='both', which='major', labelsize=12)
#axes[0, 0].set_ylim(0, 0.0009)
axes[0, 0].legend(fontsize = 14, loc = 4)
axes[0, 0].set_title('Short bond price BFGS', size=24);


axes[1, 0].plot(hypothetical_bonds_prices[0]['medium'], label = 'Random 1')
axes[1, 0].plot(hypothetical_bonds_prices[1]['medium'], label = 'Random 2')
axes[1, 0].plot(hypothetical_bonds_prices[2]['medium'], label = 'Random 3')
axes[1, 0].plot(hypothetical_bonds_prices[3]['medium'], label = 'Random 4')
axes[1, 0].plot(hypothetical_bonds_prices[-14]['medium'], label = 'recurrent')
axes[1, 0].plot(hypothetical_bonds_prices[-10]['medium'], label = 'flat')
axes[1, 0].set_xlabel('Date', fontsize = 14)
axes[1, 0].set_ylabel('Price', fontsize = 14)
axes[1, 0].tick_params(axis='both', which='major', labelsize=12)
#axes[0, 0].set_ylim(0, 0.0009)
axes[1, 0].legend(fontsize = 14, loc = 4)
axes[1, 0].set_title('Medium bond price BFGS', size=24);

axes[2, 0].plot(hypothetical_bonds_prices[0]['long'], label = 'Random 1')
axes[2, 0].plot(hypothetical_bonds_prices[1]['long'], label = 'Random 2')
axes[2, 0].plot(hypothetical_bonds_prices[2]['long'], label = 'Random 3')
axes[2, 0].plot(hypothetical_bonds_prices[3]['long'], label = 'Random 4')
axes[2, 0].plot(hypothetical_bonds_prices[-14]['long'], label = 'recurrent')
axes[2, 0].plot(hypothetical_bonds_prices[-10]['long'], label = 'flat')
axes[2, 0].set_xlabel('Date', fontsize = 14)
axes[2, 0].set_ylabel('Price', fontsize = 14)
axes[2, 0].tick_params(axis='both', which='major', labelsize=12)
#axes[0, 0].set_ylim(0, 0.0009)
axes[2, 0].legend(fontsize = 14, loc = 4)
axes[2, 0].set_title('Long bond price BFGS', size=24);

#Gauss-Newton bonds
axes[0, 1].plot(hypothetical_bonds_prices[16]['short'], label = 'Random 1)
axes[0, 1].plot(hypothetical_bonds_prices[17]['short'], label = 'Random 2)
axes[0, 1].plot(hypothetical_bonds_prices[18]['short'], label = 'Random 3)
axes[0, 1].plot(hypothetical_bonds_prices[19]['short'], label = 'Random 4)
axes[0, 1].plot(hypothetical_bonds_prices[-13]['short'], label = 'recurrent', linewidth=2.0)
axes[0, 1].plot(hypothetical_bonds_prices[-9]['short'], label = 'flat')
axes[0, 1].plot(hypothetical_bonds_prices[-4]['short'], label = 'Diebold, Li')
axes[0, 1].set_xlabel('Date', fontsize = 14)
axes[0, 1].set_ylabel('Price', fontsize = 14)
axes[0, 1].tick_params(axis='both', which='major', labelsize=12)
#axes[0, 1].set_ylim(0, 0.0009)
axes[0, 1].legend(fontsize = 14, loc = 4)
axes[0, 1].set_title('Short bond price Gauss-Newton', size=24);

axes[1, 1].plot(hypothetical_bonds_prices[16]['medium'], label = 'Random 1')
axes[1, 1].plot(hypothetical_bonds_prices[17]['medium'], label = 'Random 2')
axes[1, 1].plot(hypothetical_bonds_prices[18]['medium'], label = 'Random 3')
axes[1, 1].plot(hypothetical_bonds_prices[19]['medium'], label = 'Random 4')
axes[1, 1].plot(hypothetical_bonds_prices[-13]['medium'], label = 'recurrent', linewidth=5.0)
axes[1, 1].plot(hypothetical_bonds_prices[-9]['medium'], label = 'flat')
axes[1, 1].plot(hypothetical_bonds_prices[-4]['medium'], label = 'Diebold, Li')
axes[1, 1].set_xlabel('Date', fontsize = 14)
axes[1, 1].set_ylabel('Price', fontsize = 14)
axes[1, 1].tick_params(axis='both', which='major', labelsize=12)
#axes[1, 1].set_ylim(0, 0.0009)
axes[1, 1].legend(fontsize = 14, loc = 4)
axes[1, 1].set_title('Medium bond price Gauss-Newton', size=24);

axes[2, 1].plot(hypothetical_bonds_prices[16]['long'], label = 'Random 1')
axes[2, 1].plot(hypothetical_bonds_prices[17]['long'], label = 'Random 2')
axes[2, 1].plot(hypothetical_bonds_prices[18]['long'], label = 'Random 3')
axes[2, 1].plot(hypothetical_bonds_prices[19]['long'], label = 'Random 4')
axes[2, 1].plot(hypothetical_bonds_prices[-13]['long'], label = 'recurrent', linewidth=5.0)
axes[2, 1].plot(hypothetical_bonds_prices[-9]['long'], label = 'flat')
axes[2, 1].plot(hypothetical_bonds_prices[-4]['long'], label = 'Diebold, Li')
axes[2, 1].set_xlabel('Date', fontsize = 14)
axes[2, 1].set_ylabel('Price', fontsize = 14)
axes[2, 1].tick_params(axis='both', which='major', labelsize=12)
axes[2, 1].legend(fontsize = 14, loc = 4)
axes[2, 1].set_title('Long bond price Gauss-Newton', size=24);
plt.savefig('Pictures/Bonds_prices_BFGS_Gauss_Newton.png')

# %%
figure, axes = plt.subplots(nrows=3, ncols=2,figsize=(15, 20))

#Nelder-Mead bonds
axes[0, 0].plot(hypothetical_bonds_prices[32]['short'], label = 'Random 1')
axes[0, 0].plot(hypothetical_bonds_prices[33]['short'], label = 'Random 2')
axes[0, 0].plot(hypothetical_bonds_prices[34]['short'], label = 'Random 3')
axes[0, 0].plot(hypothetical_bonds_prices[35]['short'], label = 'Random 4')
axes[0, 0].plot(hypothetical_bonds_prices[-12]['short'], label = 'Recurrent', linewidth=5.0)
axes[0, 0].plot(hypothetical_bonds_prices[-8]['short'], label = 'Flat')
axes[0, 0].plot(hypothetical_bonds_prices[-3]['short'], label = 'Diebold, Li')
axes[0, 0].set_xlabel('Date', fontsize = 14)
axes[0, 0].set_ylabel('Price', fontsize = 14)
axes[0, 0].tick_params(axis='both', which='major', labelsize=12)
axes[0, 0].legend(fontsize = 14, loc = 4)
axes[0, 0].set_title('Short bond price Nelder-Mead', size=24);


axes[1, 0].plot(hypothetical_bonds_prices[32]['medium'], label = 'Random 1')
axes[1, 0].plot(hypothetical_bonds_prices[33]['medium'], label = 'Random 2')
axes[1, 0].plot(hypothetical_bonds_prices[34]['medium'], label = 'Random 3')
axes[1, 0].plot(hypothetical_bonds_prices[35]['medium'], label = 'Random 4')
axes[1, 0].plot(hypothetical_bonds_prices[-12]['medium'], label = 'Recurrent', linewidth=5.0)
axes[1, 0].plot(hypothetical_bonds_prices[-8]['medium'], label = 'Flat')
axes[1, 0].plot(hypothetical_bonds_prices[-3]['medium'], label = 'Diebold, Li')
axes[1, 0].set_xlabel('Date', fontsize = 14)
axes[1, 0].set_ylabel('Price', fontsize = 14)
axes[1, 0].tick_params(axis='both', which='major', labelsize=12)
#axes[0, 0].set_ylim(0, 0.0009)
axes[1, 0].legend(fontsize = 14, loc = 4)
axes[1, 0].set_title('Medium bond price Nelder-Mead', size=24);

axes[2, 0].plot(hypothetical_bonds_prices[32]['long'], label = 'Random 1')
axes[2, 0].plot(hypothetical_bonds_prices[33]['long'], label = 'Random 2')
axes[2, 0].plot(hypothetical_bonds_prices[34]['long'], label = 'Random 3')
axes[2, 0].plot(hypothetical_bonds_prices[35]['long'], label = 'Random 4')
axes[2, 0].plot(hypothetical_bonds_prices[-12]['long'], label = 'Recurrent', linewidth=5.0)
axes[2, 0].plot(hypothetical_bonds_prices[-8]['long'], label = 'Flat')
axes[2, 0].plot(hypothetical_bonds_prices[-3]['long'], label = 'Diebold, Li')
axes[2, 0].set_xlabel('Date', fontsize = 14)
axes[2, 0].set_ylabel('Price', fontsize = 14)
axes[2, 0].tick_params(axis='both', which='major', labelsize=12)
#axes[0, 0].set_ylim(0, 0.0009)
axes[2, 0].legend(fontsize = 14, loc = 4)
axes[2, 0].set_title('Long bond price Nelder-Mead', size=24);

#Powell bonds
#axes[0, 1].plot(hypothetical_bonds_prices[48]['short'], label = 'Random 1')
#axes[0, 1].plot(hypothetical_bonds_prices[49]['short'], label = 'Random 2')
#axes[0, 1].plot(hypothetical_bonds_prices[50]['short'], label = 'Random 3')
#axes[0, 1].plot(hypothetical_bonds_prices[51]['short'], label = 'Random 4')
axes[0, 1].plot(hypothetical_bonds_prices[-11]['short'], label = 'Recurrent', linewidth=2.0)
#axes[0, 1].plot(hypothetical_bonds_prices[-7]['short'], label = 'Flat')
#axes[0, 1].plot(hypothetical_bonds_prices[-2]['short'], label = 'Diebold, Li')
axes[0, 1].set_xlabel('Date', fontsize = 14)
axes[0, 1].set_ylabel('Price', fontsize = 14)
axes[0, 1].tick_params(axis='both', which='major', labelsize=12)
axes[0, 1].legend(fontsize = 14, loc = 1)
axes[0, 1].set_title('Short bond price Powell', size=24);

axes[1, 1].plot(hypothetical_bonds_prices[48]['medium'], label = 'Random 1')
axes[1, 1].plot(hypothetical_bonds_prices[49]['medium'], label = 'Random 2')
axes[1, 1].plot(hypothetical_bonds_prices[50]['medium'], label = 'Random 3')
axes[1, 1].plot(hypothetical_bonds_prices[51]['medium'], label = 'Random 4')
axes[1, 1].plot(hypothetical_bonds_prices[-11]['medium'], label = 'Recurrent', linewidth=5.0)
axes[1, 1].plot(hypothetical_bonds_prices[-7]['medium'], label = 'Flat')
axes[1, 1].plot(hypothetical_bonds_prices[-2]['medium'], label = 'Diebold, Li')
axes[1, 1].set_xlabel('Date', fontsize = 14)
axes[1, 1].set_ylabel('Price', fontsize = 14)
axes[1, 1].tick_params(axis='both', which='major', labelsize=12)
axes[1, 1].legend(fontsize = 14, loc = 4)
axes[1, 1].set_title('Medium bond price Powell', size=24);

axes[2, 1].plot(hypothetical_bonds_prices[48]['long'], label = 'Random 1')
axes[2, 1].plot(hypothetical_bonds_prices[49]['long'], label = 'Random 2')
axes[2, 1].plot(hypothetical_bonds_prices[50]['long'], label = 'Random 3')
axes[2, 1].plot(hypothetical_bonds_prices[51]['long'], label = 'Random 4')
axes[2, 1].plot(hypothetical_bonds_prices[-11]['long'], label = 'Recurrent', linewidth=5.0)
axes[2, 1].plot(hypothetical_bonds_prices[-7]['long'], label = 'Flat')
axes[2, 1].plot(hypothetical_bonds_prices[-2]['long'], label = 'Diebold, Li')
axes[2, 1].set_xlabel('Date', fontsize = 14)
axes[2, 1].set_ylabel('Price', fontsize = 14)
axes[2, 1].tick_params(axis='both', which='major', labelsize=12)
axes[2, 1].legend(fontsize = 14, loc = 4)
axes[2, 1].set_title('Long bond price Powell', size=24);
plt.savefig('Pictures/Bonds_prices_Nelder_Mead_Powell.png')

# %% [markdown]
# ## PSO

# %%
plt.figure(figsize = (15,7.5))
plt.title('Short bond price PSO', fontsize = 24)
plt.plot(hypothetical_bonds_prices[-6]['short'], label = 'PSO')
plt.plot(hypothetical_bonds_prices[-1]['short'], label = 'CBR', linewidth=5.0)
plt.xlabel('Date', fontsize = 24)
plt.ylabel('Price', fontsize = 24)
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
plt.legend(fontsize = 14);

# %%
plt.figure(figsize = (15,7.5))
plt.title('Medium bond price PSO', fontsize = 24)
plt.plot(hypothetical_bonds_prices[-6]['medium'], label = 'PSO')
plt.plot(hypothetical_bonds_prices[-1]['medium'], label = 'CBR', linewidth=5.0)
plt.xlabel('Date', fontsize = 24)
plt.ylabel('Price', fontsize = 24)
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
plt.legend(fontsize = 14);

# %%
plt.figure(figsize = (15,7.5))
plt.title('Long bond price PSO', fontsize = 24)
plt.plot(hypothetical_bonds_prices[-6]['long'], label = 'PSO')
plt.plot(hypothetical_bonds_prices[-1]['long'], label = 'CBR', linewidth=5.0)
plt.xlabel('Date', fontsize = 24)
plt.ylabel('Price', fontsize = 24)
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
plt.legend(fontsize = 14);

# %% [markdown]
# # Variance of bond prices

# %% [markdown]
# We will exclude prices above certain threshold

# %%
bfgs_list = []
for i in bfgs_indicies:
    bfgs_list.append(hypothetical_bonds_prices[i])
    
gauss_newton_list = []
for i in gauss_newton_indicies:
    gauss_newton_list.append(hypothetical_bonds_prices[i])

nelder_mead_list = []
for i in nelder_mead_indicies:
    nelder_mead_list.append(hypothetical_bonds_prices[i])

powell_list = []
for i in powell_indicies:
    powell_list.append(hypothetical_bonds_prices[i])
    
bfgs_bonds_prices = pd.concat(bfgs_list, axis=1, sort=False)
gauss_newton_bonds_prices = pd.concat(gauss_newton_list, axis=1, sort=False)
nelder_mead_bonds_prices = pd.concat(nelder_mead_list, axis=1, sort=False)
powell_bonds_prices = pd.concat(powell_list, axis=1, sort=False)

# %%
threshold = 1000

figure, axes = plt.subplots(nrows=1, ncols=2,figsize=(15, 7))

axes[0].plot(bfgs_bonds_prices['short'][bfgs_bonds_prices['short'] < threshold].std(axis = 1), label = 'BFGS')
axes[0].plot(gauss_newton_bonds_prices['short'][gauss_newton_bonds_prices['short'] < threshold].std(axis = 1), label = 'Gauss-Newton')
axes[0].plot(nelder_mead_bonds_prices['short'][nelder_mead_bonds_prices['short'] < threshold].std(axis = 1), label = 'Nelder-Mead')
axes[0].plot(powell_bonds_prices['short'][powell_bonds_prices['short'] < threshold].std(axis = 1), label = 'Powell')
axes[0].set_xlabel('Date', fontsize = 14)
axes[0].set_ylabel('Std', fontsize = 14)
axes[0].tick_params(axis='both', which='major', labelsize=12)
axes[0].legend(fontsize = 10, loc = 2)
axes[0].set_title('Short bond', size=24)
axes[0].grid()

#axes[1].plot(bfgs_bonds_prices['medium'][bfgs_bonds_prices['medium'] < threshold].std(axis = 1), label = 'BFGS')
#axes[1].plot(gauss_newton_bonds_prices['medium'][gauss_newton_bonds_prices['medium'] < threshold].std(axis = 1), label = 'Gauss-Newton')
#axes[1].plot(nelder_mead_bonds_prices['medium'][nelder_mead_bonds_prices['medium'] < threshold].std(axis = 1), label = 'Nelder-Mead')
#axes[1].plot(powell_bonds_prices['medium'][powell_bonds_prices['medium'] < threshold].std(axis = 1), label = 'Powell')
#axes[1].set_xlabel('Date', fontsize = 14)
#axes[1].set_ylabel('Std', fontsize = 14)
#axes[1].tick_params(axis='both', which='major', labelsize=12)
#axes[1].legend(fontsize = 10, loc = 2)
#axes[1].set_title('Medium bond', size=24)
#axes[1].grid()

axes[1].plot(bfgs_bonds_prices['long'][bfgs_bonds_prices['long'] < threshold].std(axis = 1), label = 'BFGS')
axes[1].plot(gauss_newton_bonds_prices['long'][gauss_newton_bonds_prices['long'] < threshold].std(axis = 1), label = 'Gauss-Newton')
axes[1].plot(nelder_mead_bonds_prices['long'][nelder_mead_bonds_prices['long'] < threshold].std(axis = 1), label = 'Nelder-Mead')
axes[1].plot(powell_bonds_prices['long'][powell_bonds_prices['long'] < threshold].std(axis = 1), label = 'Powell')
axes[1].set_xlabel('Date', fontsize = 14)
axes[1].set_ylabel('Std', fontsize = 14)
axes[1].tick_params(axis='both', which='major', labelsize=12)
axes[1].legend(fontsize = 10, loc = 2)
axes[1].set_title('Long bond', size=24)
axes[1].grid()
plt.savefig('Pictures/Bonds_prices_std_presentation.png');

# %%
values_names = ['rand_1', 'rand_2', 'rand_3', 'rand_4', 'rand_5', 'rand_6', 'rand_7', 'rand_8', 'rand_9',
               'rand_10', 'rand_11', 'rand_12', 'rand_13', 'rand_14', 'rand_15', 'rand_16', 'recurrent',
               'flat_rate', 'diebold_li']

# %%
short_left_threshold, short_right_threshold = 90, 110
medium_left_threshold, medium_right_threshold = 90, 120
long_left_threshold, long_right_threshold = 100, 150

# %%
bfgs_absurd_short_bond = ((bfgs_bonds_prices['short'] < short_left_threshold) | (bfgs_bonds_prices['short'] > short_right_threshold))
bfgs_absurd_medium_bond = ((bfgs_bonds_prices['medium'] < medium_left_threshold) | (bfgs_bonds_prices['medium'] > medium_right_threshold))
bfgs_absurd_long_bond = ((bfgs_bonds_prices['long'] < long_left_threshold) | (bfgs_bonds_prices['long'] > long_right_threshold))
bfgs_absurd_short_bond.columns, bfgs_absurd_medium_bond.columns, bfgs_absurd_long_bond.columns = values_names, values_names, values_names

bfgs_absurd_bonds = bfgs_absurd_short_bond.sum() + bfgs_absurd_medium_bond.sum() + bfgs_absurd_long_bond.sum()
bfgs_absurd_bonds/756*100
# Out:
# rand_1        0.264550
# rand_2        1.455026
# rand_3        3.835979
# rand_4        0.000000
# rand_5        0.000000
# rand_6        0.264550
# rand_7        0.132275
# rand_8        1.190476
# rand_9        0.000000
# rand_10       0.000000
# rand_11       0.661376
# rand_12       0.000000
# rand_13       0.000000
# rand_14       0.000000
# rand_15       1.058201
# rand_16       0.000000
# recurrent     0.000000
# flat_rate     0.000000
# diebold_li    7.804233
# dtype: float64

# %%
gauss_newton_absurd_short_bond = ((gauss_newton_bonds_prices['short'] < short_left_threshold) | (gauss_newton_bonds_prices['short'] > short_right_threshold))
gauss_newton_absurd_medium_bond = ((gauss_newton_bonds_prices['medium'] < medium_left_threshold) | (gauss_newton_bonds_prices['medium'] > medium_right_threshold))
gauss_newton_absurd_long_bond = ((gauss_newton_bonds_prices['long'] < long_left_threshold) | (gauss_newton_bonds_prices['long'] > long_right_threshold))
gauss_newton_absurd_short_bond.columns, gauss_newton_absurd_medium_bond.columns, gauss_newton_absurd_long_bond.columns = values_names, values_names, values_names

gauss_newton_absurd_bonds = gauss_newton_absurd_short_bond.sum() + gauss_newton_absurd_medium_bond.sum() + gauss_newton_absurd_long_bond.sum()
gauss_newton_absurd_bonds/756*100
# Out:
# rand_1          5.158730
# rand_2          7.671958
# rand_3         18.915344
# rand_4          0.000000
# rand_5        100.000000
# rand_6          7.010582
# rand_7          0.000000
# rand_8          0.000000
# rand_9          0.000000
# rand_10         1.190476
# rand_11         2.513228
# rand_12         0.000000
# rand_13         6.481481
# rand_14         0.000000
# rand_15         9.656085
# rand_16         7.010582
# recurrent       0.000000
# flat_rate       0.000000
# diebold_li     43.915344
# dtype: float64

# %%
nelder_mead_absurd_short_bond = ((nelder_mead_bonds_prices['short'] < short_left_threshold) | (nelder_mead_bonds_prices['short'] > short_right_threshold))
nelder_mead_absurd_medium_bond = ((nelder_mead_bonds_prices['medium'] < medium_left_threshold) | (nelder_mead_bonds_prices['medium'] > medium_right_threshold))
nelder_mead_absurd_long_bond = ((nelder_mead_bonds_prices['long'] < long_left_threshold) | (nelder_mead_bonds_prices['long'] > long_right_threshold))
nelder_mead_absurd_short_bond.columns, nelder_mead_absurd_medium_bond.columns, nelder_mead_absurd_long_bond.columns = values_names, values_names, values_names

nelder_mead_absurd_bonds = nelder_mead_absurd_short_bond.sum() + nelder_mead_absurd_medium_bond.sum() + nelder_mead_absurd_long_bond.sum()
nelder_mead_absurd_bonds/756*100
# Out:
# rand_1        0.661376
# rand_2        0.000000
# rand_3        0.000000
# rand_4        0.264550
# rand_5        0.000000
# rand_6        0.661376
# rand_7        0.000000
# rand_8        0.000000
# rand_9        0.264550
# rand_10       0.000000
# rand_11       0.264550
# rand_12       0.132275
# rand_13       0.529101
# rand_14       0.264550
# rand_15       1.058201
# rand_16       0.000000
# recurrent     0.000000
# flat_rate     0.661376
# diebold_li    0.396825
# dtype: float64

# %%
powell_absurd_short_bond = ((powell_bonds_prices['short'] < short_left_threshold) | (powell_bonds_prices['short'] > short_right_threshold))
powell_absurd_medium_bond = ((powell_bonds_prices['medium'] < medium_left_threshold) | (powell_bonds_prices['medium'] > medium_right_threshold))
powell_absurd_long_bond = ((nelder_mead_bonds_prices['long'] < long_left_threshold) | (powell_bonds_prices['long'] > long_right_threshold))
powell_absurd_short_bond.columns, powell_absurd_medium_bond.columns, powell_absurd_long_bond.columns = values_names, values_names, values_names

powell_absurd_bonds = powell_absurd_short_bond.sum() + powell_absurd_medium_bond.sum() + powell_absurd_long_bond.sum()
powell_absurd_bonds/756*100
# Out:
# rand_1        1.190476
# rand_2        1.587302
# rand_3        2.116402
# rand_4        2.116402
# rand_5        0.396825
# rand_6        0.529101
# rand_7        0.925926
# rand_8        0.793651
# rand_9        1.058201
# rand_10       3.174603
# rand_11       1.322751
# rand_12       0.000000
# rand_13       0.661376
# rand_14       0.661376
# rand_15       1.322751
# rand_16       2.380952
# recurrent     0.661376
# flat_rate     0.661376
# diebold_li    1.984127
# dtype: float64

# %%
powell_bonds_prices.shape
# Out:
# (252, 45)

# %% [markdown]
# # Distance travelled

# %% [markdown]
# ## Random values

# %%
np.random.seed(2)

rand_thetas = [np.concatenate([np.random.uniform(low=0, high=30, size = 2), 
                              np.random.uniform(low=0, high=10, size = 2), np.random.uniform(low=-10, high=10, size = 2)
                              ]) for i in range(1, 17)]

# %%
bfgs_recurrent_start = results[-14].shift()
bfgs_recurrent_start.iloc[0] = np.array([0.47981809, 14.91180919, 9.7016359, 
                                         -1.85315523, 4.29525109, -1.15038848])

gauss_newton_recurrent_start = results[-13].shift()
gauss_newton_recurrent_start.iloc[0] = np.array([0.47981809, 14.91180919, 9.7016359,
                                                 -1.85315523, 4.29525109, -1.15038848])

nelder_mead_recurrent_start = results[-12].shift()
nelder_mead_recurrent_start.iloc[0] = np.array([0.47981809, 14.91180919, 9.7016359, 
                                                -1.85315523, 4.29525109, -1.15038848])

powell_recurrent_start = results[-11].shift()
powell_recurrent_start.iloc[0] = np.array([0.47981809, 14.91180919, 9.7016359, 
                                           -1.85315523, 4.29525109, -1.15038848])

# %%
diebold_li_values = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Data/diebold_li.csv', index_col='TRADEDATE', parse_dates = True)

# %%
starting_values = rand_thetas * 4 
starting_values += [bfgs_recurrent_start, gauss_newton_recurrent_start, nelder_mead_recurrent_start, powell_recurrent_start] 
starting_values += [np.array([3, 7, 7, 0, 0, 0])] * 4 + [np.array([0, 0, 0, 0, 0, 0])]
starting_values += [diebold_li_values] * 4

# %%
distance_travelled = pd.DataFrame(np.zeros([252, 77]), index = dates, columns = results_names[:-1])

# %%
for i in range(len(starting_values)):
    distance_travelled[results_names[i]] = np.power(results[i] - starting_values[i], 2).sum(axis = 1)**0.5

# %%
distance_travelled.drop(['pso_df'], axis = 1, inplace = True)

# %%
distance_travelled.to_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Distance travelled/distance_travelled.csv')

# %%
distance_travelled = pd.read_csv('/Users/andrey_lukyanov/Google_Drive/Studies/Year_4/Курсач/Coding/Comparing-numerical-methods-for-term-structure-fitting/Distance travelled/distance_travelled.csv', index_col='TRADEDATE', parse_dates = True)

# %%
plt.figure(figsize = (15,7.5))
plt.title('Mean distance travelled on random weights', fontsize = 24)
plt.plot(distance_travelled.mean()[0:16].values, label = 'BFGS')
plt.plot(distance_travelled.mean()[16:32].values, label = 'Gauss-Newton')
plt.plot(distance_travelled.mean()[32:48].values, label = 'Nelder-Mead')
plt.plot(distance_travelled.mean()[48:64].values, label = 'Powell')
plt.xlabel('Random weight', fontsize = 24)
plt.ylabel('Mean RMSE', fontsize = 24)
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
plt.legend(fontsize = 14);

# %%
figure, axes = plt.subplots(nrows=2, ncols=2,figsize=(18, 10))

#BFGS
zeros = list(distance_travelled[results_names[-14]][(distance_travelled[results_names[-14]] == 0)].index)
for i in range(len(zeros)):
    if i == 0:
        axes[0, 0].axvline(zeros[i], 0, 1, c='red', linestyle='dashed', label = 'Recurrent with 0 distance', alpha = 0.8)
    else:
        axes[0, 0].axvline(zeros[i], 0, 1, c='red', linestyle='dashed', alpha = 0.5)
        

axes[0, 0].plot(np.log(distance_travelled[results_names[0:16]].mean(axis = 1)), label = 'Mean of random')
axes[0, 0].plot(np.log(distance_travelled[results_names[-14]]), label = 'Recurrent', c='red')
axes[0, 0].plot(np.log(distance_travelled[results_names[-10]]), label = 'Flat rate')
axes[0, 0].plot(np.log(distance_travelled[results_names[-5]]), label = 'Diebold Li')   

axes[0, 0].set_xlabel('Date', fontsize = 14)
axes[0, 0].set_ylabel('Log of distance travelled', fontsize = 14)
axes[0, 0].tick_params(axis='both', which='major', labelsize=12)
axes[0, 0].legend(fontsize = 10, loc = 3)
axes[0, 0].set_title('BFGS', size=24);

#Gauss-Newton
axes[0, 1].plot(np.log(distance_travelled[results_names[-13]]), label = 'Recurrent', c='red')
zeros = list(distance_travelled[results_names[-13]][(distance_travelled[results_names[-13]] == 0)].index)
for i in range(len(zeros)):
    if i == 0:
        axes[0, 1].axvline(zeros[i], 0, 1, c='red', linestyle='dashed', label = 'Recurrent with 0 distance', alpha = 0.5)
    else:
        axes[0, 1].axvline(zeros[i], 0, 1, c='red', linestyle='dashed', alpha = 0.5)
axes[0, 1].plot(np.log(distance_travelled[results_names[16:32]].mean(axis = 1)), label = 'Mean of random')
axes[0, 1].plot(np.log(distance_travelled[results_names[-9]]), label = 'Flat rate')
axes[0, 1].plot(np.log(distance_travelled[results_names[-4]]), label = 'Diebold Li')

axes[0, 1].set_xlabel('Date', fontsize = 14)
axes[0, 1].set_ylabel('Log of distance travelled', fontsize = 14)
axes[0, 1].tick_params(axis='both', which='major', labelsize=12)
axes[0, 1].legend(fontsize = 10, loc = 4)
axes[0, 1].set_title('Gauss-Newton', size=24);

#Nelder-Mead
axes[1, 0].plot(np.log(distance_travelled[results_names[32:48]].mean(axis = 1)), label = 'Mean of random')
axes[1, 0].plot(np.log(distance_travelled[results_names[-12]]), label = 'Recurrent', c='red')
axes[1, 0].plot(np.log(distance_travelled[results_names[-8]]), label = 'Flat rate')
axes[1, 0].plot(np.log(distance_travelled[results_names[-3]]), label = 'Diebold Li')

axes[1, 0].set_xlabel('Date', fontsize = 14)
axes[1, 0].set_ylabel('Log of distance travelled', fontsize = 14)
axes[1, 0].tick_params(axis='both', which='major', labelsize=12)
axes[1, 0].legend(fontsize = 10, loc = 3)
axes[1, 0].set_title('Nelder-Mead', size=24);

#Powell
axes[1, 1].plot(np.log(distance_travelled[results_names[48:64]].mean(axis = 1)), label = 'Mean of random')
axes[1, 1].plot(np.log(distance_travelled[results_names[-11]]), label = 'Recurrent', c='red')
axes[1, 1].plot(np.log(distance_travelled[results_names[-7]]), label = 'Flat rate')
axes[1, 1].plot(np.log(distance_travelled[results_names[-2]]), label = 'Diebold Li')

axes[1, 1].set_xlabel('Date', fontsize = 14)
axes[1, 1].set_ylabel('Log of distance travelled', fontsize = 14)
axes[1, 1].tick_params(axis='both', which='major', labelsize=12)
axes[1, 1].legend(fontsize = 10, loc = 3)
axes[1, 1].set_title('Powell', size=24);

figure.tight_layout()
plt.savefig('Pictures/Distance_travelled_presentation.png');
